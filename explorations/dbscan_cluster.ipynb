# %%
import os
from rdflib import Graph 
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.schema import Document
from dotenv import load_dotenv
from openai import OpenAI
load_dotenv()
import numpy as np

# %%
client = OpenAI()

# %%
# Load the graph
g = Graph()
g.parse("data/dunbar/bacnet.ttl", format="turtle")
# Out:
# <Graph identifier=Nc44e01bb13fe4a0fa23afa7af625f8cd (<class 'rdflib.graph.Graph'>)>

# %%
# Bacnet Devices

# Create the documents to load into the vector store
documents = []

# Define a SPARQL query for bacnet_Device
query_for_devices = """
PREFIX bacnet: <http://data.ashrae.org/bacnet/2016#>

SELECT ?device_name
WHERE {
  # ?device a bacnet:bacnet_Device ;
          bacnet:device_name ?device_name .
}
"""

# Run the query for devices
for row in g.query(query_for_devices):
    device_name = row[0]

    # Create the document
    content = device_name.value
    documents.append(Document(page_content=content, metadata={"type": "bacnet_device"}))

# %%
# Bacnet Points

# Create the documents to load into the vector store
documents = []

# Define a SPARQL query for bacnet_Point
query_for_points = """
PREFIX bacnet: <http://data.ashrae.org/bacnet/2016#>

SELECT ?device_name ?point_name ?present_value ?unit
WHERE {
  # ?point a bacnet:bacnet_Point ;
         bacnet:device_name ?device_name ;
         bacnet:object_name ?point_name ;
         bacnet:present_value ?present_value ;
         bacnet:object_units ?unit .
}
"""

# Run the query for points
for row in g.query(query_for_points):
    device_name, point_name, present_value, unit = row
    
    content = point_name.value 
    documents.append(Document(page_content=content, metadata={"type": "bacnet_point"}))

# %%
# Load the documents into the vector store
db = Chroma.from_documents(documents, OpenAIEmbeddings())

# %%
vectorstore_data = db.get(include=["embeddings", "metadatas"])
embs = vectorstore_data["embeddings"]

# %%
matrix = np.vstack(embs)
matrix.shape
# Out:
# (17122, 1536)

# %%
# Plot the data
import matplotlib.pyplot as plt

plt.scatter(matrix[:,0], matrix[:,1])
plt.show()

# %%
# Computer required parameters of DBSCAN clustering
# Use KNN to find the optimal epsilon
from sklearn.neighbors import NearestNeighbors
import numpy as np

# Find the optimal epsilon
nbrs = NearestNeighbors(n_neighbors=5).fit(matrix)

distances, indices = nbrs.kneighbors(matrix)

distances = np.sort(distances, axis=0)

# %%
# Now, get the sorted kth column (distances with kth neighbors) and plot the kNN distance plot
import matplotlib.pyplot as plt

plt.plot(distances[:, 4])
plt.show()

# %%
# Use knee locator to find the optimal epsilon
from kneed import KneeLocator

kneedle = KneeLocator(
    range(1, distances.shape[0] + 1), distances[:, 1], curve="convex", direction="increasing"
)

kneedle.knee_y
# Out:
# 0.4089550764604022

# %%
# Compute the DBSCAN clustering
from sklearn.cluster import DBSCAN

db = DBSCAN(eps=kneedle.knee_y, min_samples=3).fit(matrix)
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

# Print the results
print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# Out:
# Estimated number of clusters: 241
# Estimated number of noise points: 354

# %%
# Plot the results
import matplotlib.pyplot as plt

unique_labels = set(labels)
embs = np.array(embs)
core_samples_mask = np.zeros_like(labels, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True

colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = (labels == k)

    xy = embs[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=14)

    xy = embs[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=6)

# %%
# Create a dict of clusters and their bacnet devices
clusters = {}
for i in range(min(len(labels), len(documents))):
    if labels[i] in clusters:
        clusters[labels[i]].append(documents[i].page_content)
    else
        clusters[labels[i]] = [documents[i].page_content]

# Pretty print the clusters dict
import pprint
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(clusters)
# Out:
# {   -1: [   'P3-DISCHARGE-TEMP',
#             'P3-DISCHARGE-TEMP',
#             'PRIMARY-CW-SUCK-TEMP',
#             'PRIMARY-CW-SUCK-TEMP',
#             'ChilledWaterDeltaT',
#             'ChilledWaterDeltaT',
#             'CW-SAFE-SP',
#             'GEO-PUMP-MAX-SPEED',
#             'GEO-PUMP-MIN-SPEED',
#             'GEO-TOTAL-BTU',
#             'GEO-TOTAL-BTU',
#             'OA-ENTHALPY-SP',
#             'POOL-TEMP-SP1',
#             'POOL-TEMP-SP2',
#             'PRI-CW-FLOW-SP',
#             'PRI-LOOP-TOTAL-FLOW',
#             'CHP-ROTATION-PRG',
#             'CHP-ROTATION-PRG',
#             'DELTA/P10&P11-FAIL-PRG',
#             'MAU-1-INTEGRATION',
#             'SECONDARY-LOAD-PRG',
#             'CHILLED WATER SCHEDULE',
#             'CONDENSER PLANT SCHEDULE',
#             'POOL PAK SCHEDULE',
#             'ActiveCapacityLimit',
#             'ActiveLvgWaterTarget',
#             'AIFaultAlarm',
#             'ChillerCapacity',
#             'CompHours',
#             'CompMotorCurrentPercent',
#             'CompStarts',
#             'CondPressure',
#             'CondSatTemp',
#             'DischargeTemp',
#             'EvapPressure',
#             'LiquidLinePress',
#             'LiquidLineTemp',
#             'PowerFactor',
#             'Voltage',
#             'NetworkCapacityLimitPct',
#             'AlarmDigitalOutput',
#             'ChillerLimited',
#             'ChillerLocalRemote',
#             'CondPumpState',
#             'EvapPumpState',
#             'UnitOFF',
#             'ChillerEnable',
#             'ActiveMode',
#             'McQuayChillerType',
#             'MSIFaultAlarm',
#             'UnitStatus',
#             'ChillerOperationMode',
#             'CompSelect',
#             'PumpSelect',
#             'AuxAirHtStgs',
#             'Cmpr1ActvFlt',
#             'Cmpr1Curr',
#             'Cmpr1FaultCount',
#             'Cmpr1Mode',
#             'Cmpr2ActvFlt',
#             'Cmpr2Curr',
#             'Cmpr2FaultCount',
#             'Cmpr2Mode',
#             'CmprStgsDesired',
#             'CmprstgsDpt',
#             'CmprStgsHtCool',
#             'I129',
#             'I130',
#             'ReqOutsDprPos',
#             'RtnAirCO2Lvl',
#             'RtnFanCurr',
#             'SpclDprLim',
#             'SplyAirTemp',
#             'SplyAirTemp_F',
#             'SplyFanCurr',
#             'SurfTemp',
#             'SurfTemp_F',
#             'ActvAlmPres',
#             'AuxWtrHt1',
#             'AuxWtrHt2',
#             'Cmpr1ACCAllow',
#             'Cmpr2ACCAllow',
#             'ForceNoPurge',
#             'ForceOcc',
#             'ForcePurge',
#             'ForceUnocc',
#             'NetMaster',
#             'OccMode',
#             'PurgeModeActv',
#             'WtrFlow1OK',
#             'WtrFlow2OK',
#             'CPU Board Temperature',
#             'CPU Board Temperature',
#             'AHU-2 Zone Temp SP',
#             'Chilled Water Supply Temp',
#             'DC_Weather_Temp',
#             'DC_Weather_Temp',
#             'Hot Water Supply Temp',
#             'Database Transfer File',
#             'eDelta.dp.gz',
#             'Access Control Alarm',
#             'Access Control Alarm',
#             'Access Control Event',
#             'Access Control Event',
#             'Archival',
#             'Archival',
#             'Critical',
#             'Critical',
#             'Diagnostics',
#             'Diagnostics',
#             'Fire',
#             'Fire',
#             'Maintenance',
#             'Maintenance',
#             'Network',
#             'Network',
#             'Notification',
#             'Notification',
#             'Security',
#             'Security',
#             'AHU 1,3,5,7 SAT Reset',
#             'Alarm Interlocks',
#             'Alarm Interlocks',
#             'CHW Supply Temp Reset PG',
#             'DOAS DR Shutdown',
#             'DOAS DR Shutdown',
#             'Main',
#             'Main',
#             'TL mappings',
#             'TL mappings',
#             'Dunbar Academic Corridor',
#             'Dunbar Administrative Wing',
#             'Dunbar Armory',
#             'Dunbar Daycare Art Music',
#             'Dunbar Health Suite',
#             'Dunbar Locker Rooms',
#             'Dunbar Stage',
#             'ActiveCapacityLimit',
#             'ActiveLvgWaterTarget',
#             'AIFaultAlarm',
#             'ChillerCapacity',
#             'CompHours',
#             'CompMotorCurrentPercent',
#             'CompStarts',
#             'CondPressure',
#             'CondSatTemp',
#             'DischargeTemp',
#             'EvapPressure',
#             'LiquidLinePress',
#             'LiquidLineTemp',
#             'PowerFactor',
#             'Voltage',
#             'NetworkCapacityLimitPct',
#             'AlarmDigitalOutput',
#             'ChillerLimited',
#             'ChillerLocalRemote',
#             'CondPumpState',
#             'EvapPumpState',
#             'UnitOFF',
#             'ChillerEnable',
#             'ActiveMode',
#             'McQuayChillerType',
#             'MSIFaultAlarm',
#             'UnitStatus',
#             'ChillerOperationMode',
#             'CompSelect',
#             'PumpSelect',
#             'HW-PRIMARY-FLOW',
#             'INPUT_20',
#             'HW-OA-ENABLE-SP',
#             'OATshared6038',
#             'OATshared6038',
#             'SEC-MAX-DP-SP',
#             'SEC-MIN-DP-SP',
#             'SYSTEM-PRESSURE',
#             'SYSTEM-PRESSURE1',
#             'TOTAL-FLOW',
#             'MODBUS-PRG',
#             'MODBUS-PRG',
#             'PANEL-OFFLINE-PRG',
#             'PANEL-OFFLINE-PRG',
#             'HOT WATER SCHEDULE',
#             'TREND9 OAT TREND',
#             'DOAS-OFFLINE-PRG',
#             'BACNET_VAR.BACNET_Fire_Alarm',
#             'BACNET_VAR.BACNET_PCU_Pressure_SW',
#             'BACNET_VAR.BACNET_Surfactant_Level_Low',
#             'CALENDAR_0',
#             'c:\\etc\\override.xml',
#             'c:\\etc\\persist.bin',
#             'c:\\etc\\symxml.SYM_XML',
#             'c:\\etc\\timestmp.bin',
#             'c:\\plc\\persist.dat',
#             'c:\\plc\\persist.dat',
#             'EEPROM',
#             'NVRAM',
#             'SCHEDULE_0',
#             'LIGHTING-KW-MONTH%',
#             'SOLAR-KWHNet-Total',
#             'SOLAR-KWHNet-Total',
#             'SOLAR-REAL-TIME-KW',
#             'SOLAR-REAL-TIME-KW',
#             'SOLAR-PRG',
#             'SOLAR-PRG',
#             'LIGHTING ENERGY',
#             'MECHANICAL ENERGY',
#             'MECHANICAL ENERGY',
#             'MISC ENERY',
#             'TOTAL ENERGY',
#             'BAD-DAT-SENSOR-PRG',
#             'IT-RM2340-TEMP',
#             'IT-RM2340-TEMP',
#             'IT ROOM 2340',
#             'TEST sensor-RTL',
#             'TEST sensor-RTL',
#             'WSHP-1/2-LeadShed',
#             '3A15-TELE-TEMP-3176',
#             '3A15-TELECOM-RM-SP',
#             '3A48SERVER-ROOM-TEMP',
#             '   ',
#             'GARAGE-LEAD-EF',
#             'GARAGE-LEAD-SF',
#             'GARAGE-MIN-RUNTIME',
#             'MANUAL-ROTATE',
#             'PARKING 400',
#             'GARAGE-LEAD-FAN-PRG',
#             'GARAGE VENT SCHEDULE',
#             'MANUAL-ROTATE-RTL',
#             'TELECOM-SPACE-T',
#             'OCC&FAN',
#             'TEMPS&VALVE',
#             'COOLP_DEM',
#             'CUMD_AO',
#             'EAT',
#             'EVE_IND_NET',
#             'HIST_COD_NET',
#             'MAIN_MOD',
#             'OAFCFM',
#             'OAH',
#             'ODMD_AO',
#             'RMCO',
#             'RMH',
#             'RMP',
#             'SAH',
#             'SAT',
#             'SAT_DEW',
#             'UNIT_MOD',
#             'WHEMD_AO',
#             'XLT',
#             'CUALS_BIK',
#             'CUCHR_DO',
#             'CUER_DO',
#             'CUWNS_BIK',
#             'CUWVR_DO',
#             'EDCMD_DO',
#             'FBDS_BIK',
#             'HOL_MOD',
#             'HOL_STAT',
#             'OAFAL_BIK',
#             'OCN_MOD',
#             'OCN_STAT',
#             'OCS_MOD',
#             'SCH_MOD',
#             'UMAL_DO',
#             'UMWN_DO',
#             'UNIT_AUTHORIZ',
#             'UNITEN_BIK',
#             'UNIT_OCC',
#             'UNIT_UNON',
#             'WHECMD_DO',
#             'WHERDST_BIK',
#             'S_VcmxWshpTulsa[003].AppVer',
#             'S_VcmxWshpTulsa[004].AppVer',
#             'COOLP_DEM',
#             'CUMD_AO',
#             'EAT',
#             'EVE_IND_NET',
#             'HIST_COD_NET',
#             'MAIN_MOD',
#             'OAFCFM',
#             'OAH',
#             'ODMD_AO',
#             'RMCO',
#             'RMH',
#             'RMP',
#             'SAH',
#             'SAT',
#             'SAT_DEW',
#             'UNIT_MOD',
#             'WHEMD_AO',
#             'XLT',
#             'CUALS_BIK',
#             'CUCHR_DO',
#             'CUER_DO',
#             'CUWNS_BIK',
#             'CUWVR_DO',
#             'EDCMD_DO',
#             'FBDS_BIK',
#             'HOL_MOD',
#             'HOL_STAT',
#             'OAFAL_BIK',
#             'OCN_MOD',
#             'OCN_STAT',
#             'OCS_MOD',
#             'SCH_MOD',
#             'UMAL_DO',
#             'UMWN_DO',
#             'UNIT_AUTHORIZ',
#             'UNITEN_BIK',
#             'UNIT_OCC',
#             'UNIT_UNON',
#             'WHECMD_DO',
#             'WHERDST_BIK',
#             'HW-HX-VAVLE',
#             'DOMESTIC HOT WATER',
#             'HW-HX-PID',
#             'General',
#             'Trend',
#             'DHW SCHEDULE',
#             'OA-DEWPOINT',
#             'OA-ENTHALPY',
#             'OA-WETBULB',
#             'DEWPOINT-PRG',
#             'WETBULB-PRG',
#             'Boiler Blocking Code',
#             'Boiler Lockout Code',
#             'Boiler Status Code',
#             'Cascade Current Power',
#             'Cascade Total Power',
#             'Firing Rate',
#             'Flue Temperature',
#             'Inlet Temperature',
#             'System Cascade Setpoint',
#             '0-10 Volt Input/Rate Cmd/SP Cmd',
#             'Coils',
#             'Configuration',
#             'System Return Temperature',
#             'Tank Setpoint',
#             'Tank Temperature',
#             'Air Pressure Switch',
#             'Alarm Contacts',
#             'Auto Reset High Limit',
#             'Blocked Drain Switch',
#             'CH Pump',
#             'DHW Pump',
#             'Flame',
#             'Flow Switch',
#             'Gas Pressure Switch',
#             'Gas Valve',
#             'Louver Proving Switch',
#             'Run-time Contacts',
#             'Tank Thermostat',
#             'Tank Thermostat',
#             '7A5HIGHLIMIT'],
#     0: [   'Acceleration Time',
#            'Acceleration Time',
#            'Acceleration Time',
#            'Acceleration Time',
#            'Acceleration Time',
#            'Acceleration Time',
#            'Acceleration Time',
#            'Acceleration Time',
#            'Acceleration Time',
#            'Acceleration Time',
#            'Acceleration Time',
#            'Acceleration Time',
#            'Acceleration Time',
#            'Acceleration Time'],
#     1: [   'Active Fault Code',
#            'Active Fault Code',
#            'Active Fault Code',
#            'Active Fault Code',
#            'Active Fault Code',
#            'Active Fault Code',
#            'Active Fault Code',
#            'Active Fault Code',
#            'Active Fault Code',
#            'Active Fault Code',
#            'Active Fault Code',
#            'Active Fault Code',
#            'Active Fault Code',
#            'Active Fault Code'],
#     2: [   'AnyParam ID',
#            'AnyParam Value',
#            'AnyParam ID',
#            'AnyParam Value',
#            'AnyParam ID',
#            'AnyParam Value',
#            'AnyParam ID',
#            'AnyParam Value',
#            'AnyParam ID',
#            'AnyParam Value',
#            'AnyParam ID',
#            'AnyParam Value',
#            'AnyParam ID',
#            'AnyParam Value',
#            'AnyParam ID',
#            'AnyParam Value',
#            'AnyParam ID',
#            'AnyParam Value',
#            'AnyParam ID',
#            'AnyParam Value',
#            'AnyParam ID',
#            'AnyParam Value',
#            'AnyParam ID',
#            'AnyParam Value',
#            'AnyParam ID',
#            'AnyParam Value',
#            'AnyParam ID',
#            'AnyParam Value'],
#     3: [   'Current Limit',
#            'Current Limit',
#            'Current Limit',
#            'Current Limit',
#            'Current Limit',
#            'Current Limit',
#            'Current Limit',
#            'Current Limit',
#            'Current Limit',
#            'Current Limit',
#            'Current Limit',
#            'Current Limit',
#            'Current Limit',
#            'Current Limit'],
#     4: [   'DC Link Voltage',
#            'DC Link Voltage',
#            'DC Link Voltage',
#            'DC Link Voltage',
#            'DC Link Voltage',
#            'DC Link Voltage',
#            'DC Link Voltage',
#            'DC Link Voltage',
#            'DC Link Voltage',
#            'DC Link Voltage',
#            'DC Link Voltage',
#            'DC Link Voltage',
#            'DC Link Voltage',
#            'DC Link Voltage'],
#     5: [   'Deceleration Time',
#            'Deceleration Time',
#            'Deceleration Time',
#            'Deceleration Time',
#            'Deceleration Time',
#            'Deceleration Time',
#            'Deceleration Time',
#            'Deceleration Time',
#            'Deceleration Time',
#            'Deceleration Time',
#            'Deceleration Time',
#            'Deceleration Time',
#            'Deceleration Time',
#            'Deceleration Time'],
#     6: [   'FBFixedControlWord PDI 0',
#            'FBGeneralControlWord PDI 1',
#            'FBFixedControlWord_10',
#            'FBFixedControlWord_11',
#            'FBFixedControlWord_12',
#            'FBFixedControlWord_13',
#            'FBFixedControlWord_14',
#            'FBFixedControlWord_15',
#            'FBFixedControlWord_3',
#            'FBFixedControlWord_4',
#            'FBFixedControlWord_5',
#            'FBFixedControlWord_6',
#            'FBFixedControlWord_7',
#            'FBFixedControlWord_8',
#            'FBFixedControlWord_9',
#            'FBFixedControlWord PDI 0',
#            'FBGeneralControlWord PDI 1',
#            'FBFixedControlWord_10',
#            'FBFixedControlWord_11',
#            'FBFixedControlWord_12',
#            'FBFixedControlWord_13',
#            'FBFixedControlWord_14',
#            'FBFixedControlWord_15',
#            'FBFixedControlWord_3',
#            'FBFixedControlWord_4',
#            'FBFixedControlWord_5',
#            'FBFixedControlWord_6',
#            'FBFixedControlWord_7',
#            'FBFixedControlWord_8',
#            'FBFixedControlWord_9',
#            'FBFixedControlWord PDI 0',
#            'FBGeneralControlWord PDI 1',
#            'FBFixedControlWord_10',
#            'FBFixedControlWord_11',
#            'FBFixedControlWord_12',
#            'FBFixedControlWord_13',
#            'FBFixedControlWord_14',
#            'FBFixedControlWord_15',
#            'FBFixedControlWord_3',
#            'FBFixedControlWord_4',
#            'FBFixedControlWord_5',
#            'FBFixedControlWord_6',
#            'FBFixedControlWord_7',
#            'FBFixedControlWord_8',
#            'FBFixedControlWord_9',
#            'FBFixedControlWord PDI 0',
#            'FBGeneralControlWord PDI 1',
#            'FBFixedControlWord_10',
#            'FBFixedControlWord_11',
#            'FBFixedControlWord_12',
#            'FBFixedControlWord_13',
#            'FBFixedControlWord_14',
#            'FBFixedControlWord_15',
#            'FBFixedControlWord_3',
#            'FBFixedControlWord_4',
#            'FBFixedControlWord_5',
#            'FBFixedControlWord_6',
#            'FBFixedControlWord_7',
#            'FBFixedControlWord_8',
#            'FBFixedControlWord_9',
#            'FBFixedControlWord PDI 0',
#            'FBGeneralControlWord PDI 1',
#            'FBFixedControlWord_10',
#            'FBFixedControlWord_11',
#            'FBFixedControlWord_12',
#            'FBFixedControlWord_13',
#            'FBFixedControlWord_14',
#            'FBFixedControlWord_15',
#            'FBFixedControlWord_3',
#            'FBFixedControlWord_4',
#            'FBFixedControlWord_5',
#            'FBFixedControlWord_6',
#            'FBFixedControlWord_7',
#            'FBFixedControlWord_8',
#            'FBFixedControlWord_9',
#            'FBFixedControlWord PDI 0',
#            'FBGeneralControlWord PDI 1',
#            'FBFixedControlWord_10',
#            'FBFixedControlWord_11',
#            'FBFixedControlWord_12',
#            'FBFixedControlWord_13',
#            'FBFixedControlWord_14',
#            'FBFixedControlWord_15',
#            'FBFixedControlWord_3',
#            'FBFixedControlWord_4',
#            'FBFixedControlWord_5',
#            'FBFixedControlWord_6',
#            'FBFixedControlWord_7',
#            'FBFixedControlWord_8',
#            'FBFixedControlWord_9',
#            'FBFixedControlWord PDI 0',
#            'FBGeneralControlWord PDI 1',
#            'FBFixedControlWord_10',
#            'FBFixedControlWord_11',
#            'FBFixedControlWord_12',
#            'FBFixedControlWord_13',
#            'FBFixedControlWord_14',
#            'FBFixedControlWord_15',
#            'FBFixedControlWord_3',
#            'FBFixedControlWord_4',
#            'FBFixedControlWord_5',
#            'FBFixedControlWord_6',
#            'FBFixedControlWord_7',
#            'FBFixedControlWord_8',
#            'FBFixedControlWord_9',
#            'FBFixedControlWord PDI 0',
#            'FBGeneralControlWord PDI 1',
#            'FBFixedControlWord_10',
#            'FBFixedControlWord_11',
#            'FBFixedControlWord_12',
#            'FBFixedControlWord_13',
#            'FBFixedControlWord_14',
#            'FBFixedControlWord_15',
#            'FBFixedControlWord_3',
#            'FBFixedControlWord_4',
#            'FBFixedControlWord_5',
#            'FBFixedControlWord_6',
#            'FBFixedControlWord_7',
#            'FBFixedControlWord_8',
#            'FBFixedControlWord_9',
#            'FBFixedControlWord PDI 0',
#            'FBGeneralControlWord PDI 1',
#            'FBFixedControlWord_10',
#            'FBFixedControlWord_11',
#            'FBFixedControlWord_12',
#            'FBFixedControlWord_13',
#            'FBFixedControlWord_14',
#            'FBFixedControlWord_15',
#            'FBFixedControlWord_3',
#            'FBFixedControlWord_4',
#            'FBFixedControlWord_5',
#            'FBFixedControlWord_6',
#            'FBFixedControlWord_7',
#            'FBFixedControlWord_8',
#            'FBFixedControlWord_9',
#            'FBFixedControlWord PDI 0',
#            'FBGeneralControlWord PDI 1',
#            'FBFixedControlWord_10',
#            'FBFixedControlWord_11',
#            'FBFixedControlWord_12',
#            'FBFixedControlWord_13',
#            'FBFixedControlWord_14',
#            'FBFixedControlWord_15',
#            'FBFixedControlWord_3',
#            'FBFixedControlWord_4',
#            'FBFixedControlWord_5',
#            'FBFixedControlWord_6',
#            'FBFixedControlWord_7',
#            'FBFixedControlWord_8',
#            'FBFixedControlWord_9',
#            'FBFixedControlWord PDI 0',
#            'FBGeneralControlWord PDI 1',
#            'FBFixedControlWord_10',
#            'FBFixedControlWord_11',
#            'FBFixedControlWord_12',
#            'FBFixedControlWord_13',
#            'FBFixedControlWord_14',
#            'FBFixedControlWord_15',
#            'FBFixedControlWord_3',
#            'FBFixedControlWord_4',
#            'FBFixedControlWord_5',
#            'FBFixedControlWord_6',
#            'FBFixedControlWord_7',
#            'FBFixedControlWord_8',
#            'FBFixedControlWord_9',
#            'FBFixedControlWord PDI 0',
#            'FBGeneralControlWord PDI 1',
#            'FBFixedControlWord_10',
#            'FBFixedControlWord_11',
#            'FBFixedControlWord_12',
#            'FBFixedControlWord_13',
#            'FBFixedControlWord_14',
#            'FBFixedControlWord_15',
#            'FBFixedControlWord_3',
#            'FBFixedControlWord_4',
#            'FBFixedControlWord_5',
#            'FBFixedControlWord_6',
#            'FBFixedControlWord_7',
#            'FBFixedControlWord_8',
#            'FBFixedControlWord_9',
#            'FBFixedControlWord PDI 0',
#            'FBGeneralControlWord PDI 1',
#            'FBFixedControlWord_10',
#            'FBFixedControlWord_11',
#            'FBFixedControlWord_12',
#            'FBFixedControlWord_13',
#            'FBFixedControlWord_14',
#            'FBFixedControlWord_15',
#            'FBFixedControlWord_3',
#            'FBFixedControlWord_4',
#            'FBFixedControlWord_5',
#            'FBFixedControlWord_6',
#            'FBFixedControlWord_7',
#            'FBFixedControlWord_8',
#            'FBFixedControlWord_9',
#            'FBFixedControlWord PDI 0',
#            'FBGeneralControlWord PDI 1',
#            'FBFixedControlWord_10',
#            'FBFixedControlWord_11',
#            'FBFixedControlWord_12',
#            'FBFixedControlWord_13',
#            'FBFixedControlWord_14',
#            'FBFixedControlWord_15',
#            'FBFixedControlWord_3',
#            'FBFixedControlWord_4',
#            'FBFixedControlWord_5',
#            'FBFixedControlWord_6',
#            'FBFixedControlWord_7',
#            'FBFixedControlWord_8',
#            'FBFixedControlWord_9'],
#     7: [   'FBFixedStatusWord PDO 0',
#            'FBGeneralStatusWord PDO 1',
#            'FBFixedStatusWord PDO 0',
#            'FBGeneralStatusWord PDO 1',
#            'FBFixedStatusWord PDO 0',
#            'FBGeneralStatusWord PDO 1',
#            'FBFixedStatusWord PDO 0',
#            'FBGeneralStatusWord PDO 1',
#            'FBFixedStatusWord PDO 0',
#            'FBGeneralStatusWord PDO 1',
#            'FBFixedStatusWord PDO 0',
#            'FBGeneralStatusWord PDO 1',
#            'FBFixedStatusWord PDO 0',
#            'FBGeneralStatusWord PDO 1',
#            'FBFixedStatusWord PDO 0',
#            'FBGeneralStatusWord PDO 1',
#            'FBFixedStatusWord PDO 0',
#            'FBGeneralStatusWord PDO 1',
#            'FBFixedStatusWord PDO 0',
#            'FBGeneralStatusWord PDO 1',
#            'FBFixedStatusWord PDO 0',
#            'FBGeneralStatusWord PDO 1',
#            'FBFixedStatusWord PDO 0',
#            'FBGeneralStatusWord PDO 1',
#            'FBFixedStatusWord PDO 0',
#            'FBGeneralStatusWord PDO 1',
#            'FBFixedStatusWord PDO 0',
#            'FBGeneralStatusWord PDO 1'],
#     8: [   'FBProcessDataIn1',
#            'FBProcessDataIn2',
#            'FBProcessDataIn3',
#            'FBProcessDataIn4',
#            'FBProcessDataOut1',
#            'FBProcessDataOut2',
#            'FBProcessDataOut3',
#            'FBProcessDataOut4',
#            'FBProcessDataOut5',
#            'FBProcessDataOut6',
#            'FBProcessDataOut7',
#            'FBProcessDataOut8',
#            'FBProcessDataIn1',
#            'FBProcessDataIn2',
#            'FBProcessDataIn3',
#            'FBProcessDataIn4',
#            'FBProcessDataOut1',
#            'FBProcessDataOut2',
#            'FBProcessDataOut3',
#            'FBProcessDataOut4',
#            'FBProcessDataOut5',
#            'FBProcessDataOut6',
#            'FBProcessDataOut7',
#            'FBProcessDataOut8',
#            'FBProcessDataIn1',
#            'FBProcessDataIn2',
#            'FBProcessDataIn3',
#            'FBProcessDataIn4',
#            'FBProcessDataOut1',
#            'FBProcessDataOut2',
#            'FBProcessDataOut3',
#            'FBProcessDataOut4',
#            'FBProcessDataOut5',
#            'FBProcessDataOut6',
#            'FBProcessDataOut7',
#            'FBProcessDataOut8',
#            'FBProcessDataIn1',
#            'FBProcessDataIn2',
#            'FBProcessDataIn3',
#            'FBProcessDataIn4',
#            'FBProcessDataOut1',
#            'FBProcessDataOut2',
#            'FBProcessDataOut3',
#            'FBProcessDataOut4',
#            'FBProcessDataOut5',
#            'FBProcessDataOut6',
#            'FBProcessDataOut7',
#            'FBProcessDataOut8',
#            'FBProcessDataIn1',
#            'FBProcessDataIn2',
#            'FBProcessDataIn3',
#            'FBProcessDataIn4',
#            'FBProcessDataOut1',
#            'FBProcessDataOut2',
#            'FBProcessDataOut3',
#            'FBProcessDataOut4',
#            'FBProcessDataOut5',
#            'FBProcessDataOut6',
#            'FBProcessDataOut7',
#            'FBProcessDataOut8',
#            'FBProcessDataIn1',
#            'FBProcessDataIn2',
#            'FBProcessDataIn3',
#            'FBProcessDataIn4',
#            'FBProcessDataOut1',
#            'FBProcessDataOut2',
#            'FBProcessDataOut3',
#            'FBProcessDataOut4',
#            'FBProcessDataOut5',
#            'FBProcessDataOut6',
#            'FBProcessDataOut7',
#            'FBProcessDataOut8',
#            'FBProcessDataIn1',
#            'FBProcessDataIn2',
#            'FBProcessDataIn3',
#            'FBProcessDataIn4',
#            'FBProcessDataOut1',
#            'FBProcessDataOut2',
#            'FBProcessDataOut3',
#            'FBProcessDataOut4',
#            'FBProcessDataOut5',
#            'FBProcessDataOut6',
#            'FBProcessDataOut7',
#            'FBProcessDataOut8',
#            'FBProcessDataIn1',
#            'FBProcessDataIn2',
#            'FBProcessDataIn3',
#            'FBProcessDataIn4',
#            'FBProcessDataOut1',
#            'FBProcessDataOut2',
#            'FBProcessDataOut3',
#            'FBProcessDataOut4',
#            'FBProcessDataOut5',
#            'FBProcessDataOut6',
#            'FBProcessDataOut7',
#            'FBProcessDataOut8',
#            'FBProcessDataIn1',
#            'FBProcessDataIn2',
#            'FBProcessDataIn3',
#            'FBProcessDataIn4',
#            'FBProcessDataOut1',
#            'FBProcessDataOut2',
#            'FBProcessDataOut3',
#            'FBProcessDataOut4',
#            'FBProcessDataOut5',
#            'FBProcessDataOut6',
#            'FBProcessDataOut7',
#            'FBProcessDataOut8',
#            'FBProcessDataIn1',
#            'FBProcessDataIn2',
#            'FBProcessDataIn3',
#            'FBProcessDataIn4',
#            'FBProcessDataOut1',
#            'FBProcessDataOut2',
#            'FBProcessDataOut3',
#            'FBProcessDataOut4',
#            'FBProcessDataOut5',
#            'FBProcessDataOut6',
#            'FBProcessDataOut7',
#            'FBProcessDataOut8',
#            'FBProcessDataIn1',
#            'FBProcessDataIn2',
#            'FBProcessDataIn3',
#            'FBProcessDataIn4',
#            'FBProcessDataOut1',
#            'FBProcessDataOut2',
#            'FBProcessDataOut3',
#            'FBProcessDataOut4',
#            'FBProcessDataOut5',
#            'FBProcessDataOut6',
#            'FBProcessDataOut7',
#            'FBProcessDataOut8',
#            'FBProcessDataIn1',
#            'FBProcessDataIn2',
#            'FBProcessDataIn3',
#            'FBProcessDataIn4',
#            'FBProcessDataOut1',
#            'FBProcessDataOut2',
#            'FBProcessDataOut3',
#            'FBProcessDataOut4',
#            'FBProcessDataOut5',
#            'FBProcessDataOut6',
#            'FBProcessDataOut7',
#            'FBProcessDataOut8',
#            'FBProcessDataIn1',
#            'FBProcessDataIn2',
#            'FBProcessDataIn3',
#            'FBProcessDataIn4',
#            'FBProcessDataOut1',
#            'FBProcessDataOut2',
#            'FBProcessDataOut3',
#            'FBProcessDataOut4',
#            'FBProcessDataOut5',
#            'FBProcessDataOut6',
#            'FBProcessDataOut7',
#            'FBProcessDataOut8',
#            'FBProcessDataIn1',
#            'FBProcessDataIn2',
#            'FBProcessDataIn3',
#            'FBProcessDataIn4',
#            'FBProcessDataOut1',
#            'FBProcessDataOut2',
#            'FBProcessDataOut3',
#            'FBProcessDataOut4',
#            'FBProcessDataOut5',
#            'FBProcessDataOut6',
#            'FBProcessDataOut7',
#            'FBProcessDataOut8'],
#     9: [   'Frequency Setpoint',
#            'At Setpoint',
#            'Frequency Setpoint',
#            'At Setpoint',
#            'Frequency Setpoint',
#            'At Setpoint',
#            'Frequency Setpoint',
#            'At Setpoint',
#            'AT SETPOINT',
#            'Frequency Setpoint',
#            'At Setpoint',
#            'Frequency Setpoint',
#            'At Setpoint',
#            'Frequency Setpoint',
#            'At Setpoint',
#            'Frequency Setpoint',
#            'At Setpoint',
#            'Frequency Setpoint',
#            'At Setpoint',
#            'Frequency Setpoint',
#            'At Setpoint',
#            'Frequency Setpoint',
#            'At Setpoint',
#            'AT SETPOINT',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'AT SETPOINT',
#            'AT SETPOINT',
#            'AT SETPOINT',
#            'Frequency Setpoint',
#            'At Setpoint',
#            'Frequency Setpoint',
#            'At Setpoint',
#            'AT SETPOINT',
#            'Frequency Setpoint',
#            'At Setpoint',
#            'Outlet Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint',
#            'Setpoint'],
#     10: [   'Kilowatt Hours',
#             'Kilowatt Hours Total',
#             'Kilowatt Hours',
#             'Kilowatt Hours Total',
#             'Kilowatt Hours',
#             'Kilowatt Hours Total',
#             'Kilowatt Hours',
#             'Kilowatt Hours Total',
#             'Kilowatt Hours',
#             'Kilowatt Hours Total',
#             'Kilowatt Hours',
#             'Kilowatt Hours Total',
#             'Kilowatt Hours',
#             'Kilowatt Hours Total',
#             'Kilowatts',
#             'Kilowatts',
#             'Kilowatt Hours',
#             'Kilowatt Hours Total',
#             'Kilowatt Hours',
#             'Kilowatt Hours Total',
#             'Kilowatt Hours',
#             'Kilowatt Hours Total',
#             'Kilowatt Hours',
#             'Kilowatt Hours Total',
#             'Kilowatt Hours',
#             'Kilowatt Hours Total',
#             'Kilowatt Hours',
#             'Kilowatt Hours Total',
#             'Kilowatt Hours',
#             'Kilowatt Hours Total'],
#     11: [   'Load (Power)',
#             'Load (Power)',
#             'Load (Power)',
#             'Load (Power)',
#             'Load (Power)',
#             'Load (Power)',
#             'Load (Power)',
#             'Load (Power)',
#             'Load (Power)',
#             'Load (Power)',
#             'Load (Power)',
#             'Load (Power)',
#             'Load (Power)',
#             'Load (Power)'],
#     12: [   'Max Frequency',
#             'Min Frequency',
#             'Max Frequency',
#             'Min Frequency',
#             'Max Frequency',
#             'Min Frequency',
#             'Max Frequency',
#             'Min Frequency',
#             'Max Frequency',
#             'Min Frequency',
#             'Max Frequency',
#             'Min Frequency',
#             'Max Frequency',
#             'Min Frequency',
#             'Max Frequency',
#             'Min Frequency',
#             'Max Frequency',
#             'Min Frequency',
#             'Max Frequency',
#             'Min Frequency',
#             'Max Frequency',
#             'Min Frequency',
#             'Max Frequency',
#             'Min Frequency',
#             'Max Frequency',
#             'Min Frequency',
#             'Max Frequency',
#             'Min Frequency'],
#     13: [   'Motor Current',
#             'Motor Speed',
#             'Motor Voltage',
#             'Motor Current',
#             'Motor Speed',
#             'Motor Voltage',
#             'Motor Current',
#             'Motor Speed',
#             'Motor Voltage',
#             'Motor Current',
#             'Motor Speed',
#             'Motor Voltage',
#             'Motor Current',
#             'Motor Speed',
#             'Motor Voltage',
#             'Motor Current',
#             'Motor Speed',
#             'Motor Voltage',
#             'Motor Current',
#             'Motor Speed',
#             'Motor Voltage',
#             'Motor Current',
#             'Motor Speed',
#             'Motor Voltage',
#             'Motor Current',
#             'Motor Speed',
#             'Motor Voltage',
#             'Motor Current',
#             'Motor Speed',
#             'Motor Voltage',
#             'Motor Current',
#             'Motor Speed',
#             'Motor Voltage',
#             'Motor Current',
#             'Motor Speed',
#             'Motor Voltage',
#             'Motor Current',
#             'Motor Speed',
#             'Motor Voltage',
#             'Motor Current',
#             'Motor Speed',
#             'Motor Voltage'],
#     14: [   'Motor Temp Rise',
#             'Motor Temp Rise',
#             'Motor Temp Rise',
#             'Motor Temp Rise',
#             'Motor Temp Rise',
#             'Motor Temp Rise',
#             'Motor Temp Rise',
#             'Motor Temp Rise',
#             'Motor Temp Rise',
#             'Motor Temp Rise',
#             'Motor Temp Rise',
#             'Motor Temp Rise',
#             'Motor Temp Rise',
#             'Motor Temp Rise'],
#     15: [   'Motor Torque',
#             'Motor Torque',
#             'Motor Torque',
#             'Motor Torque',
#             'Motor Torque',
#             'Motor Torque',
#             'Motor Torque',
#             'Motor Torque',
#             'Motor Torque',
#             'Motor Torque',
#             'Motor Torque',
#             'Motor Torque',
#             'Motor Torque',
#             'Motor Torque'],
#     16: [   'Operating Days',
#             'Operating Days',
#             'Operating Days',
#             'Operating Days',
#             'Operating Days',
#             'Operating Days',
#             'Operating Days',
#             'Operating Days',
#             'Operating Days',
#             'Operating Days',
#             'Operating Days',
#             'Operating Days',
#             'Operating Days',
#             'Operating Days'],
#     17: [   'Operating Hours',
#             'Operating Hours',
#             'Operating Hours',
#             'Operating Hours',
#             'Operating Hours',
#             'Operating Hours',
#             'Operating Hours',
#             'Operating Hours',
#             'Operating Hours',
#             'Operating Hours',
#             'Operating Hours',
#             'Operating Hours',
#             'Operating Hours',
#             'Operating Hours'],
#     18: [   'Output Frequency',
#             'Output Frequency',
#             'Output Frequency',
#             'Output Frequency',
#             'Output Frequency',
#             'Output Frequency',
#             'Output Frequency',
#             'Output Frequency',
#             'Output Frequency',
#             'Output Frequency',
#             'Output Frequency',
#             'Output Frequency',
#             'Output Frequency',
#             'Output Frequency'],
#     19: [   'Speed Reference',
#             'Speed Reference',
#             'Speed Reference',
#             'Speed Reference',
#             'Speed Reference',
#             'Speed Reference',
#             'Speed Reference',
#             'Speed Reference',
#             'Speed Reference',
#             'Speed Reference',
#             'Speed Reference',
#             'Speed Reference',
#             'Speed Reference',
#             'Speed Reference'],
#     20: [   'Torque Reference',
#             'Torque Reference',
#             'Torque Reference',
#             'Torque Reference',
#             'Torque Reference',
#             'Torque Reference',
#             'Torque Reference',
#             'Torque Reference',
#             'Torque Reference',
#             'Torque Reference',
#             'Torque Reference',
#             'Torque Reference',
#             'Torque Reference',
#             'Torque Reference'],
#     21: [   'Unit Temperature',
#             'Unit Temperature',
#             'Unit Temperature',
#             'Unit Temperature',
#             'Unit Temperature',
#             'Unit Temperature',
#             'Unit Temperature',
#             'Unit Temperature',
#             'Unit Temperature',
#             'Unit Temperature',
#             'Unit Temperature',
#             'Unit Temperature',
#             'Unit Temperature',
#             'Unit Temperature'],
#     22: [   'At Zero Speed',
#             'At Zero Speed',
#             'At Zero Speed',
#             'At Zero Speed',
#             'At Zero Speed',
#             'At Zero Speed',
#             'At Zero Speed',
#             'At Zero Speed',
#             'At Zero Speed',
#             'At Zero Speed',
#             'At Zero Speed',
#             'At Zero Speed',
#             'At Zero Speed',
#             'At Zero Speed'],
#     23: [   'Fault State',
#             'Fault State',
#             'Fault State',
#             'Fault State',
#             'Fault State',
#             'Fault State',
#             'Fault State',
#             'Fault State',
#             'Fault State',
#             'Fault State',
#             'Fault State',
#             'Fault State',
#             'Fault State',
#             'Fault State'],
#     24: [   'Fwd/Rev CMD',
#             'Fwd/Rev CMD',
#             'Fwd/Rev CMD',
#             'Fwd/Rev CMD',
#             'FWD/REV CMD',
#             'Fwd/Rev CMD',
#             'Fwd/Rev CMD',
#             'Fwd/Rev CMD',
#             'Fwd/Rev CMD',
#             'Fwd/Rev CMD',
#             'Fwd/Rev CMD',
#             'Fwd/Rev CMD',
#             'FWD/REV CMD',
#             'FWD/REV CMD',
#             'FWD/REV CMD',
#             'FWD/REV CMD',
#             'Fwd/Rev CMD',
#             'Fwd/Rev CMD',
#             'FWD/REV CMD',
#             'Fwd/Rev CMD'],
#     25: [   'Fwd/Rev State',
#             'Fwd/Rev State',
#             'Fwd/Rev State',
#             'Fwd/Rev State',
#             'Fwd/Rev State',
#             'Fwd/Rev State',
#             'Fwd/Rev State',
#             'Fwd/Rev State',
#             'Fwd/Rev State',
#             'Fwd/Rev State',
#             'Fwd/Rev State',
#             'Fwd/Rev State',
#             'Fwd/Rev State',
#             'Fwd/Rev State'],
#     26: [   'General 0',
#             'General 1',
#             'General 2',
#             'General 3',
#             'General 4',
#             'General 5',
#             'General 6',
#             'General 7',
#             'General 0',
#             'General 1',
#             'General 2',
#             'General 3',
#             'General 4',
#             'General 5',
#             'General 6',
#             'General 7',
#             'General 0',
#             'General 1',
#             'General 2',
#             'General 3',
#             'General 4',
#             'General 5',
#             'General 6',
#             'General 7',
#             'General 0',
#             'General 1',
#             'General 2',
#             'General 3',
#             'General 4',
#             'General 5',
#             'General 6',
#             'General 7',
#             'General 0',
#             'General 1',
#             'General 2',
#             'General 3',
#             'General 4',
#             'General 5',
#             'General 6',
#             'General 7',
#             'General 0',
#             'General 1',
#             'General 2',
#             'General 3',
#             'General 4',
#             'General 5',
#             'General 6',
#             'General 7',
#             'General 0',
#             'General 1',
#             'General 2',
#             'General 3',
#             'General 4',
#             'General 5',
#             'General 6',
#             'General 7',
#             'General 0',
#             'General 1',
#             'General 2',
#             'General 3',
#             'General 4',
#             'General 5',
#             'General 6',
#             'General 7',
#             'General 0',
#             'General 1',
#             'General 2',
#             'General 3',
#             'General 4',
#             'General 5',
#             'General 6',
#             'General 7',
#             'General 0',
#             'General 1',
#             'General 2',
#             'General 3',
#             'General 4',
#             'General 5',
#             'General 6',
#             'General 7',
#             'General 0',
#             'General 1',
#             'General 2',
#             'General 3',
#             'General 4',
#             'General 5',
#             'General 6',
#             'General 7',
#             'General 0',
#             'General 1',
#             'General 2',
#             'General 3',
#             'General 4',
#             'General 5',
#             'General 6',
#             'General 7',
#             'General 0',
#             'General 1',
#             'General 2',
#             'General 3',
#             'General 4',
#             'General 5',
#             'General 6',
#             'General 7',
#             'General 0',
#             'General 1',
#             'General 2',
#             'General 3',
#             'General 4',
#             'General 5',
#             'General 6',
#             'General 7'],
#     27: [   'Ready State',
#             'Ready State',
#             'Ready State',
#             'Ready State',
#             'Ready State',
#             'Ready State',
#             'Ready State',
#             'Ready State',
#             'Ready State',
#             'Ready State',
#             'Ready State',
#             'Ready State',
#             'Ready State',
#             'Ready State'],
#     28: [   'Reset Fault',
#             'Reset Fault',
#             'Reset Fault',
#             'Reset Fault',
#             'Reset Fault',
#             'Reset Fault',
#             'Reset Fault',
#             'Reset Fault',
#             'Reset Fault',
#             'Reset Fault',
#             'Reset Fault',
#             'Reset Fault',
#             'Reset Fault',
#             'Reset Fault'],
#     29: [   'Run/Stop CMD',
#             'Run/Stop CMD',
#             'Run/Stop CMD',
#             'Run/Stop CMD',
#             'RUN/STOP CMD',
#             'Run/Stop CMD',
#             'Run/Stop CMD',
#             'Run/Stop CMD',
#             'Run/Stop CMD',
#             'Run/Stop CMD',
#             'Run/Stop CMD',
#             'Run/Stop CMD',
#             'RUN/STOP CMD',
#             'RUN/STOP CMD',
#             'RUN/STOP CMD',
#             'RUN/STOP CMD',
#             'Run/Stop CMD',
#             'Run/Stop CMD',
#             'RUN/STOP CMD',
#             'Run/Stop CMD'],
#     30: [   'Run/Stop State',
#             'Run/Stop State',
#             'Run/Stop State',
#             'Run/Stop State',
#             'Run/Stop State',
#             'Run/Stop State',
#             'Run/Stop State',
#             'Run/Stop State',
#             'Run/Stop State',
#             'Run/Stop State',
#             'Run/Stop State',
#             'Run/Stop State',
#             'Run/Stop State',
#             'Run/Stop State'],
#     31: [   'Warning State',
#             'Warning State',
#             'Warning State',
#             'Warning State',
#             'Warning State',
#             'Warning State',
#             'Warning State',
#             'Warning State',
#             'Warning State',
#             'Warning State',
#             'Warning State',
#             'Warning State',
#             'Warning State',
#             'Warning State'],
#     32: [   'Energy Rate',
#             'Energy Rate Multiplier Units',
#             'Energy Total Multiplier Units',
#             'Energy Rate',
#             'Energy Rate Multiplier Units',
#             'Energy Total Multiplier Units',
#             'Energy Rate',
#             'Energy Rate Multiplier Units',
#             'Energy Total Multiplier Units',
#             'Energy Rate',
#             'Energy Rate Multiplier Units',
#             'Energy Total Multiplier Units'],
#     33: [   'Return Temperature',
#             'Return Temperature',
#             'Return Temperature',
#             'Return Temperature'],
#     34: [   'Supply Temperature',
#             'Supply Temperature',
#             'Supply Temperature',
#             'Supply Temperature',
#             'Outlet Temperature',
#             'System Supply Temperature'],
#     35: [   'Volume Rate',
#             'Volume Rate Multiplier Units',
#             'Volume Total Multiplier Units',
#             'Volume Rate',
#             'Volume Rate Multiplier Units',
#             'Volume Total Multiplier Units',
#             'Volume Rate',
#             'Volume Rate Multiplier Units',
#             'Volume Total Multiplier Units',
#             'Volume Rate',
#             'Volume Rate Multiplier Units',
#             'Volume Total Multiplier Units'],
#     36: [   'Aux Input Total',
#             'Aux Input Total',
#             'Aux Input Total',
#             'Aux Input Total'],
#     37: [   'BACnet Instance',
#             'BACnet Instance',
#             'BACnet Instance',
#             'BACnet Instance'],
#     38: [   'Mode 1 Energy Total',
#             'Mode 1 Volume Total',
#             'Mode 2 Energy Total',
#             'Mode 2 Volume Total',
#             'Zero Mode 1 Energy Total',
#             'Zero Mode 1 Volume Total',
#             'Zero Mode 2 Energy Total',
#             'Zero Mode 2 Volume Total',
#             'Mode 1 Energy Total',
#             'Mode 1 Volume Total',
#             'Mode 2 Energy Total',
#             'Mode 2 Volume Total',
#             'Zero Mode 1 Energy Total',
#             'Zero Mode 1 Volume Total',
#             'Zero Mode 2 Energy Total',
#             'Zero Mode 2 Volume Total',
#             'Mode 1 Energy Total',
#             'Mode 1 Volume Total',
#             'Mode 2 Energy Total',
#             'Mode 2 Volume Total',
#             'Zero Mode 1 Energy Total',
#             'Zero Mode 1 Volume Total',
#             'Zero Mode 2 Energy Total',
#             'Zero Mode 2 Volume Total',
#             'Mode 1 Energy Total',
#             'Mode 1 Volume Total',
#             'Mode 2 Energy Total',
#             'Mode 2 Volume Total',
#             'Zero Mode 1 Energy Total',
#             'Zero Mode 1 Volume Total',
#             'Zero Mode 2 Energy Total',
#             'Zero Mode 2 Volume Total'],
#     39: [   'Mode 1 Mode 2 indication',
#             'Mode 1 Mode 2 indication',
#             'Mode 1 Mode 2 indication',
#             'Mode 1 Mode 2 indication'],
#     40: [   'Operating Mode',
#             'Operating Mode',
#             'Operating Mode',
#             'Operating Mode'],
#     41: [   'Temperature Units',
#             'Temperature Units',
#             'Temperature Units',
#             'Temperature Units'],
#     42: [   'Zero Aux Input Total',
#             'Zero Aux Input Total',
#             'Zero Aux Input Total',
#             'Zero Aux Input Total'],
#     43: [   'Airflow',
#             'Airflow',
#             'Airflow',
#             'Airflow',
#             'Airflow',
#             'Airflow',
#             'Airflow'],
#     44: [   'Pressure',
#             'Pressure',
#             'Pressure',
#             'Pressure',
#             'Pressure',
#             'Pressure',
#             'Pressure'],
#     45: [   'Temperature',
#             'Temperature',
#             'Temperature',
#             'Temperature',
#             'Temperature',
#             'Temperature',
#             'Temperature'],
#     46: [   'Airflow Traverse',
#             'Airflow Traverse',
#             'Airflow Traverse',
#             'Airflow Traverse',
#             'Airflow Traverse',
#             'Airflow Traverse',
#             'Airflow Traverse'],
#     47: [   'Baud Rate',
#             'Baud Rate',
#             'Baud Rate',
#             'Baud Rate',
#             'Baud Rate',
#             'Baud Rate',
#             'Baud Rate'],
#     48: [   'Free area',
#             'Free area',
#             'Free area',
#             'Free area',
#             'Free area',
#             'Free area',
#             'Free area'],
#     49: [   'Temperature Traverse',
#             'Temperature Traverse',
#             'Temperature Traverse',
#             'Temperature Traverse',
#             'Temperature Traverse',
#             'Temperature Traverse',
#             'Temperature Traverse'],
#     50: [   'ANALOG INPUT 1',
#             'ANALOG INPUT 2',
#             'ANALOG OUTPUT 1',
#             'ANALOG_INPUT_0',
#             'ANALOG_INPUT_1',
#             'ANALOG_INPUT_1',
#             'ANALOG_INPUT_2',
#             'ANALOG_INPUT_2',
#             'ANALOG_INPUT_3',
#             'ANALOG_INPUT_3',
#             'ANALOG_INPUT_4',
#             'ANALOG_INPUT_5',
#             'ANALOG_INPUT_6',
#             'ANALOG_INPUT_7',
#             'BINARY_INPUT_0',
#             'BINARY_INPUT_0',
# ...
#              'BackupControl',
#              'BackupControl',
#              'BackupControl',
#              'BackupControl',
#              'BackupControl',
#              'BackupControl',
#              'BackupControl',
#              'BackupControl',
#              'BackupControl',
#              'BackupControl',
#              'BackupControl',
#              'BackupControl',
#              'BackupControl',
#              'BackupControl',
#              'BackupControl',
#              'BackupControl'],
#     223: [   'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup',
#              'SetupBackup'],
#     224: [   'NC_0',
#              'NC_1',
#              'NC_65',
#              'NC_0',
#              'NC_1',
#              'NC_65',
#              'NC_0',
#              'NC_1',
#              'NC_65',
#              'NC_0',
#              'NC_1',
#              'NC_65',
#              'NC_0',
#              'NC_1',
#              'NC_65',
#              'NC_0',
#              'NC_1',
#              'NC_65',
#              'NC_0',
#              'NC_1',
#              'NC_65',
#              'NC_0',
#              'NC_1',
#              'NC_65'],
#     225: [   'CBAS Alarm (1)',
#              'CBAS Alarm (1)',
#              'CBAS Alarm (2)',
#              'CBAS Alarm (3)',
#              'CBAS Alarm (4)',
#              'CBAS Alarm (5)',
#              'CBAS Alarm (6)'],
#     226: [   'GARAGE-CO-1',
#              'GARAGE-CO-2',
#              'GARAGE-NO2-1',
#              'GARAGE-NO2-2',
#              'GARAGE-CO-SP',
#              'GARAGE-NO2-SP',
#              'GARAGE-CO-PURGE',
#              'GARAGE-NO2-PURGE',
#              'CO-PURGE-PRG',
#              'NO2-PURGE-PRG',
#              'GARAGE-CO-PURGE-RTL',
#              'GARAGE-NO2-PURGE-RTL'],
#     227: [   'EFANMD_AO',
#              'FBDMD_AO',
#              'SFANMD_AO',
#              'EFANMD_AO',
#              'FBDMD_AO',
#              'SFANMD_AO'],
#     228: ['HEATP_DEM', 'REHEAT_DEM', 'HEATP_DEM', 'REHEAT_DEM'],
#     229: ['OAT', 'OAT_DEW', 'OAT', 'OAT_DEW'],
#     230: ['RMT', 'RMT_DEW', 'RMT', 'RMT_DEW'],
#     231: ['UM_AL_NET', 'UM_AL', 'UM_AL_NET', 'UM_AL'],
#     232: ['UM_WN_NET', 'UM_WN', 'UM_WN_NET', 'UM_WN'],
#     233: [   'EDST_BIK',
#              'EMSTPST_BIK',
#              'FFLTST_BIK',
#              'MDST_BIK',
#              'OCCSWST_BIK',
#              'ODST_BIK',
#              'OFLTST_BIK',
#              'RFLTST_BIK',
#              'EDST_BIK',
#              'EMSTPST_BIK',
#              'FFLTST_BIK',
#              'MDST_BIK',
#              'OCCSWST_BIK',
#              'ODST_BIK',
#              'OFLTST_BIK',
#              'RFLTST_BIK'],
#     234: ['EFANCMD_DO', 'SFANCMD_DO', 'EFANCMD_DO', 'SFANCMD_DO'],
#     235: ['EFANST_BIK', 'SFANST_BIK', 'EFANST_BIK', 'SFANST_BIK'],
#     236: [   'S_VcmxWshpTulsa[003].AlmGrp1',
#              'S_VcmxWshpTulsa[003].AlmGrp2',
#              'S_VcmxWshpTulsa[003].AlmGrp3',
#              'S_VcmxWshpTulsa[003].AlmSts',
#              'S_VcmxWshpTulsa[003].ByPasDmp',
#              'S_VcmxWshpTulsa[003].CdFan1',
#              'S_VcmxWshpTulsa[003].CdFan2',
#              'S_VcmxWshpTulsa[003].ClSt',
#              'S_VcmxWshpTulsa[003].CO2Level',
#              'S_VcmxWshpTulsa[003].CoilTp',
#              'S_VcmxWshpTulsa[003].CtrlSts',
#              'S_VcmxWshpTulsa[003].CtrlTp',
#              'S_VcmxWshpTulsa[003].DptStM',
#              'S_VcmxWshpTulsa[003].DuctPr',
#              'S_VcmxWshpTulsa[003].EcoPos',
#              'S_VcmxWshpTulsa[003].EtCFM',
#              'S_VcmxWshpTulsa[003].ExRlys12',
#              'S_VcmxWshpTulsa[003].ExRlys34',
#              'S_VcmxWshpTulsa[003].HdPr1',
#              'S_VcmxWshpTulsa[003].HdPr2',
#              'S_VcmxWshpTulsa[003].HtSt',
#              'S_VcmxWshpTulsa[003].InRh',
#              'S_VcmxWshpTulsa[003].InRhStM',
#              'S_VcmxWshpTulsa[003].MdClPos',
#              'S_VcmxWshpTulsa[003].MdCmp2',
#              'S_VcmxWshpTulsa[003].MdHt2Pos',
#              'S_VcmxWshpTulsa[003].MdHtPos',
#              'S_VcmxWshpTulsa[003].OaCFM',
#              'S_VcmxWshpTulsa[003].OACfmStM',
#              'S_VcmxWshpTulsa[003].OaDwpt',
#              'S_VcmxWshpTulsa[003].OaRh',
#              'S_VcmxWshpTulsa[003].OaTp',
#              'S_VcmxWshpTulsa[003].OaWtbl',
#              'S_VcmxWshpTulsa[003].OnRlys',
#              'S_VcmxWshpTulsa[003].RaDmp',
#              'S_VcmxWshpTulsa[003].RaTp',
#              'S_VcmxWshpTulsa[003].RfPr',
#              'S_VcmxWshpTulsa[003].Rt2Pos',
#              'S_VcmxWshpTulsa[003].SaCFM',
#              'S_VcmxWshpTulsa[003].SaTp',
#              'S_VcmxWshpTulsa[003].SaTpStM',
#              'S_VcmxWshpTulsa[003].SpcTp',
#              'S_VcmxWshpTulsa[003].TpDmnd',
#              'S_VcmxWshpTulsa[003].UnitMode',
#              'S_VcmxWshpTulsa[003].VfdBwPos',
#              'S_VcmxWshpTulsa[003].VfdExPos',
#              'S_VcmxWshpTulsa[003].WaterTpA',
#              'S_VcmxWshpTulsa[003].WaterTpB',
#              'S_VcmxWshpTulsa[003].CO2St',
#              'S_VcmxWshpTulsa[003].CoilTpSt',
#              'S_VcmxWshpTulsa[003].DptSt',
#              'S_VcmxWshpTulsa[003].DuctPrSt',
#              'S_VcmxWshpTulsa[003].InRhSt',
#              'S_VcmxWshpTulsa[003].MinEcoSt',
#              'S_VcmxWshpTulsa[003].OACfmRs',
#              'S_VcmxWshpTulsa[003].OACfmSt',
#              'S_VcmxWshpTulsa[003].OaTpOst',
#              'S_VcmxWshpTulsa[003].OcpClSt',
#              'S_VcmxWshpTulsa[003].OcpHtSt',
#              'S_VcmxWshpTulsa[003].PreHtSp',
#              'S_VcmxWshpTulsa[003].RaTpOst',
#              'S_VcmxWshpTulsa[003].RfPrSt',
#              'S_VcmxWshpTulsa[003].RmVFDPos',
#              'S_VcmxWshpTulsa[003].SaClSt',
#              'S_VcmxWshpTulsa[003].SaHtSt',
#              'S_VcmxWshpTulsa[003].SaTpOst',
#              'S_VcmxWshpTulsa[003].SchdFrc',
#              'S_VcmxWshpTulsa[003].SpcTpOst',
#              'S_VcmxWshpTulsa[003].UnClOst',
#              'S_VcmxWshpTulsa[003].UnHtOst',
#              'S_VcmxWshpTulsa[003].WmupSt',
#              'S_VcmxWshpTulsa[003].WtblSt',
#              'S_VcmxWshpTulsa[003].A1LktAlm',
#              'S_VcmxWshpTulsa[003].A1LSPAlm',
#              'S_VcmxWshpTulsa[003].A2LktAlm',
#              'S_VcmxWshpTulsa[003].A2LSPAlm',
#              'S_VcmxWshpTulsa[003].B1LktAlm',
#              'S_VcmxWshpTulsa[003].B1LSPAlm',
#              'S_VcmxWshpTulsa[003].B2LktAlm',
#              'S_VcmxWshpTulsa[003].B2LSPAlm',
#              'S_VcmxWshpTulsa[003].ClEnbl',
#              'S_VcmxWshpTulsa[003].CO2Cfg',
#              'S_VcmxWshpTulsa[003].ComMAlm',
#              'S_VcmxWshpTulsa[003].CtrlTpCF',
#              'S_VcmxWshpTulsa[003].CtrlTpHF',
#              'S_VcmxWshpTulsa[003].DrtFlAlm',
#              'S_VcmxWshpTulsa[003].EcoEnbl',
#              'S_VcmxWshpTulsa[003].ExRly1',
#              'S_VcmxWshpTulsa[003].ExRly10',
#              'S_VcmxWshpTulsa[003].ExRly11',
#              'S_VcmxWshpTulsa[003].ExRly12',
#              'S_VcmxWshpTulsa[003].ExRly13',
#              'S_VcmxWshpTulsa[003].ExRly14',
#              'S_VcmxWshpTulsa[003].ExRly15',
#              'S_VcmxWshpTulsa[003].ExRly16',
#              'S_VcmxWshpTulsa[003].ExRly2',
#              'S_VcmxWshpTulsa[003].ExRly3',
#              'S_VcmxWshpTulsa[003].ExRly4',
#              'S_VcmxWshpTulsa[003].ExRly5',
#              'S_VcmxWshpTulsa[003].ExRly6',
#              'S_VcmxWshpTulsa[003].ExRly7',
#              'S_VcmxWshpTulsa[003].ExRly8',
#              'S_VcmxWshpTulsa[003].ExRly9',
#              'S_VcmxWshpTulsa[003].FanDly',
#              'S_VcmxWshpTulsa[003].HiSaAlm',
#              'S_VcmxWshpTulsa[003].HtEnbl',
#              'S_VcmxWshpTulsa[003].LoSaAlm',
#              'S_VcmxWshpTulsa[003].LWT1Alm',
#              'S_VcmxWshpTulsa[003].LWT2Alm',
#              'S_VcmxWshpTulsa[003].MchClAlm',
#              'S_VcmxWshpTulsa[003].MchHtAlm',
#              'S_VcmxWshpTulsa[003].MdHt2Ins',
#              'S_VcmxWshpTulsa[003].OaTpAlm',
#              'S_VcmxWshpTulsa[003].OnRly1',
#              'S_VcmxWshpTulsa[003].OnRly2',
#              'S_VcmxWshpTulsa[003].OnRly3',
#              'S_VcmxWshpTulsa[003].OnRly4',
#              'S_VcmxWshpTulsa[003].OnRly5',
#              'S_VcmxWshpTulsa[003].PofAlm',
#              'S_VcmxWshpTulsa[003].PofCfg',
#              'S_VcmxWshpTulsa[003].POWF1Alm',
#              'S_VcmxWshpTulsa[003].POWF2Alm',
#              'S_VcmxWshpTulsa[003].Rt2Ins',
#              'S_VcmxWshpTulsa[003].SaTpAlm',
#              'S_VcmxWshpTulsa[003].SmokeAlm',
#              'S_VcmxWshpTulsa[003].SpcTpAlm',
#              'S_VcmxWshpTulsa[004].AlmGrp1',
#              'S_VcmxWshpTulsa[004].AlmGrp2',
#              'S_VcmxWshpTulsa[004].AlmGrp3',
#              'S_VcmxWshpTulsa[004].AlmGrp5',
#              'S_VcmxWshpTulsa[004].AlmSts',
#              'S_VcmxWshpTulsa[004].ByPasDmp',
#              'S_VcmxWshpTulsa[004].CdFan1',
#              'S_VcmxWshpTulsa[004].CdFan2',
#              'S_VcmxWshpTulsa[004].CdFan21',
#              'S_VcmxWshpTulsa[004].CdFan22',
#              'S_VcmxWshpTulsa[004].ClSt',
#              'S_VcmxWshpTulsa[004].CO2Level',
#              'S_VcmxWshpTulsa[004].CoilTp',
#              'S_VcmxWshpTulsa[004].CtrlSts',
#              'S_VcmxWshpTulsa[004].CtrlTp',
#              'S_VcmxWshpTulsa[004].DptStM',
#              'S_VcmxWshpTulsa[004].DuctPr',
#              'S_VcmxWshpTulsa[004].EcoPos',
#              'S_VcmxWshpTulsa[004].EtCFM',
#              'S_VcmxWshpTulsa[004].ExRlys12',
#              'S_VcmxWshpTulsa[004].ExRlys34',
#              'S_VcmxWshpTulsa[004].HdPr1',
#              'S_VcmxWshpTulsa[004].HdPr2',
#              'S_VcmxWshpTulsa[004].HdPr21',
#              'S_VcmxWshpTulsa[004].HdPr22',
#              'S_VcmxWshpTulsa[004].HtSt',
#              'S_VcmxWshpTulsa[004].InRh',
#              'S_VcmxWshpTulsa[004].InRhStM',
#              'S_VcmxWshpTulsa[004].MdClPos',
#              'S_VcmxWshpTulsa[004].MdCmp2',
#              'S_VcmxWshpTulsa[004].MdHt2Pos',
#              'S_VcmxWshpTulsa[004].MdHtPos',
#              'S_VcmxWshpTulsa[004].OaCFM',
#              'S_VcmxWshpTulsa[004].OACfmStM',
#              'S_VcmxWshpTulsa[004].OaDwpt',
#              'S_VcmxWshpTulsa[004].OaRh',
#              'S_VcmxWshpTulsa[004].OaTp',
#              'S_VcmxWshpTulsa[004].OaWtbl',
#              'S_VcmxWshpTulsa[004].OnRlys',
#              'S_VcmxWshpTulsa[004].RaDmp',
#              'S_VcmxWshpTulsa[004].RaTp',
#              'S_VcmxWshpTulsa[004].RfPr',
#              'S_VcmxWshpTulsa[004].Rt2Pos',
#              'S_VcmxWshpTulsa[004].SaCFM',
#              'S_VcmxWshpTulsa[004].SaTp',
#              'S_VcmxWshpTulsa[004].SaTpStM',
#              'S_VcmxWshpTulsa[004].SpcTp',
#              'S_VcmxWshpTulsa[004].T24EcFb',
#              'S_VcmxWshpTulsa[004].TpDmnd',
#              'S_VcmxWshpTulsa[004].UnitMode',
#              'S_VcmxWshpTulsa[004].VfdBwPos',
#              'S_VcmxWshpTulsa[004].VfdExPos',
#              'S_VcmxWshpTulsa[004].WaterTpA',
#              'S_VcmxWshpTulsa[004].WaterTpB',
#              'S_VcmxWshpTulsa[004].ClHiRt',
#              'S_VcmxWshpTulsa[004].ClLoRt',
#              'S_VcmxWshpTulsa[004].CO2St',
#              'S_VcmxWshpTulsa[004].CoilTpSt',
#              'S_VcmxWshpTulsa[004].DptSt',
#              'S_VcmxWshpTulsa[004].DuctPrSt',
#              'S_VcmxWshpTulsa[004].HtHiRt',
#              'S_VcmxWshpTulsa[004].HtLoRt',
#              'S_VcmxWshpTulsa[004].InRhSt',
#              'S_VcmxWshpTulsa[004].MinEcoSt',
#              'S_VcmxWshpTulsa[004].OACfmRs',
#              'S_VcmxWshpTulsa[004].OACfmSt',
#              'S_VcmxWshpTulsa[004].OaTpOst',
#              'S_VcmxWshpTulsa[004].OcpClSt',
#              'S_VcmxWshpTulsa[004].OcpHtSt',
#              'S_VcmxWshpTulsa[004].PreHtSp',
#              'S_VcmxWshpTulsa[004].RaTpOst',
#              'S_VcmxWshpTulsa[004].RfPrSt',
#              'S_VcmxWshpTulsa[004].RmVFDPos',
#              'S_VcmxWshpTulsa[004].SaClRt',
#              'S_VcmxWshpTulsa[004].SaClSt',
#              'S_VcmxWshpTulsa[004].SaHtRt',
#              'S_VcmxWshpTulsa[004].SaHtSt',
#              'S_VcmxWshpTulsa[004].SaTpOst',
#              'S_VcmxWshpTulsa[004].SchdFrc',
#              'S_VcmxWshpTulsa[004].SpcTpOst',
#              'S_VcmxWshpTulsa[004].UnClOst',
#              'S_VcmxWshpTulsa[004].UnHtOst',
#              'S_VcmxWshpTulsa[004].WmupSt',
#              'S_VcmxWshpTulsa[004].WtblSt',
#              'S_VcmxWshpTulsa[004].A1LktAlm',
#              'S_VcmxWshpTulsa[004].A1LSPAlm',
#              'S_VcmxWshpTulsa[004].A2LktAlm',
#              'S_VcmxWshpTulsa[004].A2LSPAlm',
#              'S_VcmxWshpTulsa[004].B1LktAlm',
#              'S_VcmxWshpTulsa[004].B1LSPAlm',
#              'S_VcmxWshpTulsa[004].B2LktAlm',
#              'S_VcmxWshpTulsa[004].B2LSPAlm',
#              'S_VcmxWshpTulsa[004].ClEnbl',
#              'S_VcmxWshpTulsa[004].CO2Cfg',
#              'S_VcmxWshpTulsa[004].ComMAlm',
#              'S_VcmxWshpTulsa[004].CtrlTpCF',
#              'S_VcmxWshpTulsa[004].CtrlTpHF',
#              'S_VcmxWshpTulsa[004].DrtFlAlm',
#              'S_VcmxWshpTulsa[004].EcoEnbl',
#              'S_VcmxWshpTulsa[004].ExRly1',
#              'S_VcmxWshpTulsa[004].ExRly10',
#              'S_VcmxWshpTulsa[004].ExRly11',
#              'S_VcmxWshpTulsa[004].ExRly12',
#              'S_VcmxWshpTulsa[004].ExRly13',
#              'S_VcmxWshpTulsa[004].ExRly14',
#              'S_VcmxWshpTulsa[004].ExRly15',
#              'S_VcmxWshpTulsa[004].ExRly16',
#              'S_VcmxWshpTulsa[004].ExRly2',
#              'S_VcmxWshpTulsa[004].ExRly3',
#              'S_VcmxWshpTulsa[004].ExRly4',
#              'S_VcmxWshpTulsa[004].ExRly5',
#              'S_VcmxWshpTulsa[004].ExRly6',
#              'S_VcmxWshpTulsa[004].ExRly7',
#              'S_VcmxWshpTulsa[004].ExRly8',
#              'S_VcmxWshpTulsa[004].ExRly9',
#              'S_VcmxWshpTulsa[004].FanDly',
#              'S_VcmxWshpTulsa[004].HiSaAlm',
#              'S_VcmxWshpTulsa[004].HtEnbl',
#              'S_VcmxWshpTulsa[004].LoSaAlm',
#              'S_VcmxWshpTulsa[004].LWT1Alm',
#              'S_VcmxWshpTulsa[004].LWT2Alm',
#              'S_VcmxWshpTulsa[004].MchClAlm',
#              'S_VcmxWshpTulsa[004].MchHtAlm',
#              'S_VcmxWshpTulsa[004].MdHt2Ins',
#              'S_VcmxWshpTulsa[004].OaTpAlm',
#              'S_VcmxWshpTulsa[004].OnRly1',
#              'S_VcmxWshpTulsa[004].OnRly2',
#              'S_VcmxWshpTulsa[004].OnRly3',
#              'S_VcmxWshpTulsa[004].OnRly4',
#              'S_VcmxWshpTulsa[004].OnRly5',
#              'S_VcmxWshpTulsa[004].PofAlm',
#              'S_VcmxWshpTulsa[004].PofCfg',
#              'S_VcmxWshpTulsa[004].POWF1Alm',
#              'S_VcmxWshpTulsa[004].POWF2Alm',
#              'S_VcmxWshpTulsa[004].RaTpAlm',
#              'S_VcmxWshpTulsa[004].Rt2Ins',
#              'S_VcmxWshpTulsa[004].SaTpAlm',
#              'S_VcmxWshpTulsa[004].SmokeAlm',
#              'S_VcmxWshpTulsa[004].SpcTpAlm',
#              'S_VcmxWshpTulsa[004].T24DpAlm',
#              'S_VcmxWshpTulsa[004].T24EWISN',
#              'S_VcmxWshpTulsa[004].T24ExsOA',
#              'S_VcmxWshpTulsa[004].T24NEWS',
#              'S_VcmxWshpTulsa[004].T24TpAlm'],
#     237: ['6038-OACO2', '6038-OAH', '6038-OAT'],
#     238: [   'Discrete Inputs 1 - 16',
#              'Discrete Inputs 17 - 32',
#              'Discrete Inputs 33 - 48'],
#     239: ['Boiler Pump Speed', 'System Pump Speed', 'System Pump'],
#     240: [   'Room Thermostat 1',
#              'Room Thermostat 2',
#              'Room Thermostat 1',
#              'Room Thermostat 2',
#              'Room Thermostat 3']}
