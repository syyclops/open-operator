# %%
from rdflib import Graph 
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.schema import Document
from sklearn.cluster import KMeans
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score
import numpy as np
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Load the graph
g = Graph()
g.parse("data/dunbar/bacnet.ttl", format="turtle")
# Out:
# <Graph identifier=N4433219261c2455fbcc33b8914867cee (<class 'rdflib.graph.Graph'>)>

# %%
# Bacnet Devices

# Create the documents to load into the vector store
documents = []

# Define a SPARQL query for bacnet_Device
query_for_devices = """
PREFIX bacnet: <http://data.ashrae.org/bacnet/2016#>

SELECT ?device_name
WHERE {
  # ?device a bacnet:bacnet_Device ;
          bacnet:device_name ?device_name .
}
"""

# Run the query for devices
for row in g.query(query_for_devices):
    device_name = row[0]

    # Create the document
    content = device_name.value
    documents.append(Document(page_content=content, metadata={"type": "bacnet_device"}))

# %%
# Bacnet Points

# Create the documents to load into the vector store
documents = []

# Define a SPARQL query for bacnet_Point
query_for_points = """
PREFIX bacnet: <http://data.ashrae.org/bacnet/2016#>

SELECT ?device_name ?point_name ?present_value ?unit
WHERE {
  # ?point a bacnet:bacnet_Point ;
         bacnet:device_name ?device_name ;
         bacnet:object_name ?point_name ;
         bacnet:present_value ?present_value ;
         bacnet:object_units ?unit .
}
"""

# Run the query for points
for row in g.query(query_for_points):
    device_name, point_name, present_value, unit = row
    
    content = point_name.value + " " + present_value.value + " " + unit.value
    documents.append(Document(page_content=content, metadata={"type": "bacnet_point"}))

# %%
# Load the documents into the vector store
db = Chroma.from_documents(documents, OpenAIEmbeddings())

# %%
vectorstore_data = db.get(include=["embeddings", "metadatas"])
embs = vectorstore_data["embeddings"]
embs = np.vstack(embs)
embs.shape
# Out:
# (354, 1536)

# %%
# Plot the data
plt.scatter(embs[:,0], embs[:,1], alpha=0.1)
plt.show()

# %%
step_size = 1  # define the step size
kmin, kmax = 2, 25  # range of k values to try
sil = []  # list of silhouette scores
patience = 5  # number of iterations to continue after score decreases
counter = 0  # counter for number of iterations since score decreased
best_score = -1  # initialize with worst possible silhouette score
k_values = []  # list to store the k values

for k in tqdm(range(kmin, kmax+1, step_size)):
    kmeans = MiniBatchKMeans(n_clusters=k, n_init=10, random_state=0, batch_size=1000).fit(embs) # adjust batch_size as needed
    labels = kmeans.labels_
    score = silhouette_score(embs, labels, metric='euclidean')
    sil.append(score)
    k_values.append(k)

    # Early stopping with patience
    if score > best_score:
        best_score = score
        counter = 0  # reset counter when score improves
    else:
        counter += 1  # increment counter when score does not improve
        if counter >= patience:
            break

optimal_clusters = k_values[np.argmax(sil)]  # get the optimal number of clusters

# Plot silhouette scores
plt.plot(k_values, sil, color='blue', linewidth='3')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.axvline(x=optimal_clusters, color='red', linestyle='--')
plt.show()
print("Optimal number of clusters:", optimal_clusters)
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
#  42%|████▏     | 10/24 [00:04<00:06,  2.22it/s]
# Optimal number of clusters: 7

# %%
# Perform k-means clustering
kmeans = KMeans(n_clusters=optimal_clusters, random_state=0, n_init=10)
cluster_assignments = kmeans.fit_predict(embs)
labels = kmeans.labels_

# %%
# Plot the clusters
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import numpy as np

# Convert list to numpy array
embs_array = np.array(embs)

tsne = TSNE(n_components=2, random_state=0)
X_2d = tsne.fit_transform(embs_array)

plt.figure(figsize=(6, 5))
plt.scatter(X_2d[:, 0], X_2d[:, 1], c=cluster_assignments)
plt.show()

# %%
# Create a dictionary of clusters, with the key being the cluster number and the value being the list of documents in that cluster
cluster_dict = {}
for i in range(len(labels)):
    cluster_dict.setdefault(labels[i], []).append(documents[i])

# Print the clusters
for cluster in cluster_dict:
    print("Cluster", cluster)
    for document in cluster_dict[cluster]:
        print(document.metadata["type"], document.page_content)
    print()
# Out:
# Cluster 91
# bacnet_point Acceleration Time 60.0 seconds
# bacnet_point Deceleration Time 60.0 seconds
# bacnet_point Acceleration Time 60.0 seconds
# bacnet_point Deceleration Time 60.0 seconds
# bacnet_point Acceleration Time 60.0 seconds
# bacnet_point Deceleration Time 60.0 seconds
# bacnet_point Acceleration Time 60.0 seconds
# bacnet_point Deceleration Time 60.0 seconds
# bacnet_point ACCEL1 TIME 60.0 seconds
# bacnet_point DECEL1 TIME 60.0 seconds
# bacnet_point Acceleration Time 60.0 seconds
# bacnet_point Deceleration Time 60.0 seconds
# bacnet_point Acceleration Time 60.0 seconds
# bacnet_point Deceleration Time 60.0 seconds
# bacnet_point Acceleration Time 60.0 seconds
# bacnet_point Deceleration Time 60.0 seconds
# bacnet_point Acceleration Time 60.0 seconds
# bacnet_point Deceleration Time 60.0 seconds
# bacnet_point Acceleration Time 60.0 seconds
# bacnet_point Deceleration Time 60.0 seconds
# bacnet_point Acceleration Time 60.0 seconds
# bacnet_point Deceleration Time 60.0 seconds
# bacnet_point Acceleration Time 60.0 seconds
# bacnet_point Deceleration Time 60.0 seconds
# bacnet_point ACCEL1 TIME 60.0 seconds
# bacnet_point DECEL1 TIME 60.0 seconds
# bacnet_point ACCEL1 TIME 60.0 seconds
# bacnet_point DECEL1 TIME 60.0 seconds
# bacnet_point ACCEL1 TIME 30.0 seconds
# bacnet_point DECEL1 TIME 30.0 seconds
# bacnet_point ACCEL1 TIME 60.0 seconds
# bacnet_point DECEL1 TIME 60.0 seconds
# bacnet_point Acceleration Time 60.0 seconds
# bacnet_point Deceleration Time 60.0 seconds
# bacnet_point Acceleration Time 60.0 seconds
# bacnet_point Deceleration Time 60.0 seconds
# bacnet_point ACCEL1 TIME 60.0 seconds
# bacnet_point DECEL1 TIME 60.0 seconds
# bacnet_point Acceleration Time 60.0 seconds
# bacnet_point Deceleration Time 60.0 seconds
#
# Cluster 117
# bacnet_point Active Fault Code 0.0 noUnits
# bacnet_point AnyParam ID 0.0 noUnits
# bacnet_point AnyParam Value 384.0 noUnits
# bacnet_point Active Fault Code 0.0 noUnits
# bacnet_point AnyParam ID 0.0 noUnits
# bacnet_point AnyParam Value 0.0 noUnits
# bacnet_point Aux Input Total 0.0 noUnits
# bacnet_point Energy Rate Multiplier Units 1025.0 noUnits
# bacnet_point Energy Total Multiplier Units 1537.0 noUnits
# bacnet_point Mode 1 Mode 2 indication 2.0 noUnits
# bacnet_point Operating Mode 1.0 noUnits
# bacnet_point Volume Rate Multiplier Units 257.0 noUnits
# bacnet_point Volume Total Multiplier Units 1025.0 noUnits
# bacnet_point Aux Input Total 0.0 noUnits
# bacnet_point Energy Rate Multiplier Units 1025.0 noUnits
# bacnet_point Energy Total Multiplier Units 1537.0 noUnits
# bacnet_point Mode 1 Mode 2 indication 2.0 noUnits
# bacnet_point Operating Mode 1.0 noUnits
# bacnet_point Volume Rate Multiplier Units 257.0 noUnits
# bacnet_point Volume Total Multiplier Units 1025.0 noUnits
# bacnet_point Aux Input Total 0.0 noUnits
# bacnet_point Energy Rate Multiplier Units 1025.0 noUnits
# bacnet_point Energy Total Multiplier Units 1537.0 noUnits
# bacnet_point Mode 1 Mode 2 indication 2.0 noUnits
# bacnet_point Operating Mode 1.0 noUnits
# bacnet_point Volume Rate Multiplier Units 257.0 noUnits
# bacnet_point Volume Total Multiplier Units 1025.0 noUnits
# bacnet_point Active Fault Code 0.0 noUnits
# bacnet_point AnyParam ID 0.0 noUnits
# bacnet_point AnyParam Value 65.0 noUnits
# bacnet_point Baud Rate 38400.0 noUnits
# bacnet_point Active Fault Code 0.0 noUnits
# bacnet_point AnyParam ID 0.0 noUnits
# bacnet_point AnyParam Value 8424.0 noUnits
# bacnet_point LAST FLT 0.0 noUnits
# bacnet_point MBOX DATA 0.0 noUnits
# bacnet_point MBOX PARAM 0.0 noUnits
# bacnet_point PREV FLT 1 17.0 noUnits
# bacnet_point PREV FLT 2 17.0 noUnits
# bacnet_point Active Fault Code 0.0 noUnits
# bacnet_point AnyParam ID 0.0 noUnits
# bacnet_point AnyParam Value 0.0 noUnits
# bacnet_point Active Fault Code 0.0 noUnits
# bacnet_point AnyParam ID 0.0 noUnits
# bacnet_point AnyParam Value 0.0 noUnits
# bacnet_point Active Fault Code 0.0 noUnits
# bacnet_point AnyParam ID 0.0 noUnits
# bacnet_point AnyParam Value 0.0 noUnits
# bacnet_point CHP-10&11-PUMP-REQUEST 1.0 noUnits
# bacnet_point CHP-10&11-PUMP-REQUEST 2.0 noUnits
# bacnet_point CW-A-LOOP-LEAD-PUMP 5.0 noUnits
# bacnet_point CW-C-LOOP-LEAD-PUMP 6.0 noUnits
# bacnet_point CW-FIELD-LOOP-LAG-PUMP 3.0 noUnits
# bacnet_point CW-FIELD-LOOP-LEAD-PUMP 1.0 noUnits
# bacnet_point CW-FIELD-LOOP-SB-PUMP 2.0 noUnits
# bacnet_point GEO-LEAD-VAULT 2.0 noUnits
# bacnet_point GEO-VAULT-MAX-LEAD-DAYS 10.0 noUnits
# bacnet_point GEO-VAULT-REQUEST 2.0 noUnits
# bacnet_point LEAD-PRIMARY-CHWP 8.0 noUnits
# bacnet_point LEAD-PRIMARY-CHWP 9.0 noUnits
# bacnet_point LEAD-SECONDARY-CHWP 11.0 noUnits
# bacnet_point PRI-CWP-REQUEST 2.0 noUnits
# bacnet_point VARIABLE_44 10.0 noUnits
# bacnet_point AIFaultAlarm 0.0 noUnits
# bacnet_point AIProblemAlarm 0.0 noUnits
# bacnet_point AIWarningAlarm 0.0 noUnits
# bacnet_point CompStarts 9632.0 noUnits
# bacnet_point AuxAirHtStgs 0.0 noUnits
# bacnet_point Cmpr1ActvFlt 1.0 noUnits
# bacnet_point Cmpr1FaultCount 0.0 noUnits
# bacnet_point Cmpr1Mode 0.0 noUnits
# bacnet_point Cmpr2ActvFlt 50.0 noUnits
# bacnet_point Cmpr2FaultCount 10.0 noUnits
# bacnet_point Cmpr2Mode 0.0 noUnits
# bacnet_point CmprStgsDesired 4.0 noUnits
# bacnet_point CmprstgsDpt 4.0 noUnits
# bacnet_point CmprStgsHtCool 0.0 noUnits
# bacnet_point FuzzyDprChg 8.800000190734863 noUnits
# bacnet_point FuzzyDptCmprChg 14.5 noUnits
# bacnet_point FuzzyRatCmprChg2 12.300000190734863 noUnits
# bacnet_point SpclDprLim 0.0 noUnits
# bacnet_point AIFaultAlarm 66.0 noUnits
# bacnet_point AIProblemAlarm 0.0 noUnits
# bacnet_point AIWarningAlarm 0.0 noUnits
# bacnet_point CompStarts 6176.0 noUnits
# bacnet_point LEAD-PRI-HWP 15.0 noUnits
# bacnet_point LEAD-SEC-HWP 16.0 noUnits
# bacnet_point LEAD-WWHP 1.0 noUnits
# bacnet_point WWHP-REQUEST 0.0 noUnits
# bacnet_point WWHP-REQUEST 1.0 noUnits
# bacnet_point M3AHU03-DMPR-SPACE 1.0 noUnits
# bacnet_point M3AHU03-DMPR-SPACE 3.0 noUnits
# bacnet_point M3DOAS2-VAV-CO2-COUNT 0.0 noUnits
# bacnet_point ANALOG_INPUT_0 223.0 noUnits
# bacnet_point ANALOG_INPUT_1 222.0 noUnits
# bacnet_point ANALOG_INPUT_1 228.0 noUnits
# bacnet_point ANALOG_INPUT_2 238.0 noUnits
# bacnet_point ANALOG_INPUT_2 244.0 noUnits
# bacnet_point ANALOG_INPUT_3 222.0 noUnits
# bacnet_point ANALOG_INPUT_3 224.0 noUnits
# bacnet_point ANALOG_INPUT_4 225.0 noUnits
# bacnet_point ANALOG_INPUT_5 1500.0 noUnits
# bacnet_point ANALOG_INPUT_6 1500.0 noUnits
# bacnet_point ANALOG_INPUT_7 1500.0 noUnits
# bacnet_point EM-MS-1-1700 6562.0 noUnits
# bacnet_point EM-MS-1-1701 5229.0 noUnits
# bacnet_point EM-MS-1-1702 80.0 noUnits
# bacnet_point EM-MS-1-1703 0.0 noUnits
# bacnet_point EM-MS-2-1700 5453.0 noUnits
# bacnet_point EM-MS-2-1701 2127.0 noUnits
# bacnet_point EM-MS-2-1702 19.0 noUnits
# bacnet_point EM-MS-2-1703 0.0 noUnits
# bacnet_point M4AHU07-DMPR-HL 95.0 noUnits
# bacnet_point M4AHU07-DMPR-SPACE 0.0 noUnits
# bacnet_point M4AHU07-DMPR-SPACE 1.0 noUnits
# bacnet_point M4AHU07-DMPR-SPACE-SP 2.0 noUnits
# bacnet_point M4AHU07-SPACE-HL 2.0 noUnits
# bacnet_point M4VavGlobalVavBalOvrd 0.0 noUnits
# bacnet_point VARIABLE_123 -8.399999876173769e-30 noUnits
# bacnet_point VARIABLE_180 72.69999694824219 noUnits
# bacnet_point VARIABLE18 0.0 noUnits
# bacnet_point AHU-3DAT-FIX 0.0 noUnits
# bacnet_point AHU-3RAH-SP 50.0 noUnits
# bacnet_point INPUT23 0.0 noUnits
# bacnet_point VARIABLE18 0.0 noUnits
# bacnet_point VARIABLE23 0.0 noUnits
# bacnet_point VARIABLE24 0.0 noUnits
# bacnet_point DOAS3-DMPR-SPACE-SP 2.0 noUnits
# bacnet_point DOAS4-DMPR-SPACE 10.0 noUnits
# bacnet_point DOAS4-DMPR-SPACE 3.0 noUnits
# bacnet_point DOAS4-DMPR-SPACE-SP 3.0 noUnits
# bacnet_point DOAS5-DMPR-SPACE-SP 2.0 noUnits
# bacnet_point M5AHU01-DMPR-SPACE 0.0 noUnits
# bacnet_point M5AHU01-DMPR-SPACE-SP 1.0 noUnits
# bacnet_point M5AHU05-DMPR-SPACE 1.0 noUnits
# bacnet_point M5AHU05-DMPR-SPACE-SP 1.0 noUnits
# bacnet_point M5AHU05-MAX-DAMPER 100.0 noUnits
# bacnet_point M5AHU05-SPACE-HL 2.0 noUnits
# bacnet_point VARIABLE_80 8.0 noUnits
# bacnet_point DOAS3-DMPR-SPACE 14.0 noUnits
# bacnet_point DOAS5-DMPR-SPACE 10.0 noUnits
# bacnet_point DOAS5-DMPR-SPACE 4.0 noUnits
# bacnet_point M6DOAS3-DMPR-HL 0.0 noUnits
# bacnet_point M6DOAS3-DMPR-SPACE-SP 2.0 noUnits
# bacnet_point M6DOAS3-SPACE-HL 2.0 noUnits
# bacnet_point M6DOAS5-DMPR-HL 0.0 noUnits
# bacnet_point M6DOAS5-DMPR-SPACE-SP 0.0 noUnits
# bacnet_point M6DOAS5-SPACE-HL 2.0 noUnits
# bacnet_point M6-VAV-DMPR-OVRD 0.0 noUnits
# bacnet_point M7AHU03-DMPR-SPACE 0.0 noUnits
# bacnet_point M7AHU03-DMPR-SPACE 7.0 noUnits
# bacnet_point M7AHU03-DMPR-SPACE-SP 4.0 noUnits
# bacnet_point M7DOAS2-STAGE-DOWN 0.0 noUnits
# bacnet_point M7DOAS2-STAGE-UP 0.0 noUnits
# bacnet_point WSHP-1/2-LeadShed 0.0 noUnits
# bacnet_point Active Fault Code 0.0 noUnits
# bacnet_point AnyParam ID 0.0 noUnits
# bacnet_point AnyParam Value 0.0 noUnits
# bacnet_point Active Fault Code 0.0 noUnits
# bacnet_point AnyParam ID 0.0 noUnits
# bacnet_point AnyParam Value 0.0 noUnits
# bacnet_point Active Fault Code 0.0 noUnits
# bacnet_point AnyParam ID 0.0 noUnits
# bacnet_point AnyParam Value -512.0 noUnits
# bacnet_point Baud Rate 38400.0 noUnits
# bacnet_point Active Fault Code 0.0 noUnits
# bacnet_point AnyParam ID 0.0 noUnits
# bacnet_point AnyParam Value 0.0 noUnits
# bacnet_point Aux Input Total 0.0 noUnits
# bacnet_point Energy Rate Multiplier Units 1025.0 noUnits
# bacnet_point Energy Total Multiplier Units 1537.0 noUnits
# bacnet_point Mode 1 Mode 2 indication 2.0 noUnits
# bacnet_point Operating Mode 1.0 noUnits
# bacnet_point Volume Rate Multiplier Units 257.0 noUnits
# bacnet_point Volume Total Multiplier Units 1025.0 noUnits
# bacnet_point LAST FLT 0.0 noUnits
# bacnet_point MBOX DATA 0.0 noUnits
# bacnet_point MBOX PARAM 0.0 noUnits
# bacnet_point PREV FLT 1 17.0 noUnits
# bacnet_point PREV FLT 2 17.0 noUnits
# bacnet_point     1800.0 noUnits
# bacnet_point GARAGE-LEAD-EF 12.0 noUnits
# bacnet_point GARAGE-LEAD-SF 13.0 noUnits
# bacnet_point Baud Rate 38400.0 noUnits
# bacnet_point LAST FLT 0.0 noUnits
# bacnet_point MBOX DATA 0.0 noUnits
# bacnet_point MBOX PARAM 0.0 noUnits
# bacnet_point PREV FLT 1 17.0 noUnits
# bacnet_point PREV FLT 2 17.0 noUnits
# bacnet_point LAST FLT 14.0 noUnits
# bacnet_point MBOX DATA 0.0 noUnits
# bacnet_point MBOX PARAM 0.0 noUnits
# bacnet_point PREV FLT 1 14.0 noUnits
# bacnet_point PREV FLT 2 17.0 noUnits
# bacnet_point EVE_IND_NET 0.0 noUnits
# bacnet_point HIST_COD_NET 249.0 noUnits
# bacnet_point MAIN_MOD 2.0 noUnits
# bacnet_point UM_AL_NET 0.0 noUnits
# bacnet_point UM_WN_NET 156.0 noUnits
# bacnet_point UNIT_MOD 11.0 noUnits
# bacnet_point LAST FLT 0.0 noUnits
# bacnet_point MBOX DATA 0.0 noUnits
# bacnet_point MBOX PARAM 0.0 noUnits
# bacnet_point PREV FLT 1 17.0 noUnits
# bacnet_point PREV FLT 2 17.0 noUnits
# bacnet_point Active Fault Code 0.0 noUnits
# bacnet_point AnyParam ID 0.0 noUnits
# bacnet_point AnyParam Value 0.0 noUnits
# bacnet_point Active Fault Code 0.0 noUnits
# bacnet_point AnyParam ID 0.0 noUnits
# bacnet_point AnyParam Value 0.0 noUnits
# bacnet_point Baud Rate 38400.0 noUnits
# bacnet_point Baud Rate 38400.0 noUnits
# bacnet_point LAST FLT 0.0 noUnits
# bacnet_point MBOX DATA 0.0 noUnits
# bacnet_point MBOX PARAM 0.0 noUnits
# bacnet_point PREV FLT 1 51.0 noUnits
# bacnet_point PREV FLT 2 14.0 noUnits
# bacnet_point Active Fault Code 0.0 noUnits
# bacnet_point AnyParam ID 0.0 noUnits
# bacnet_point AnyParam Value 0.0 noUnits
# bacnet_point Baud Rate 38400.0 noUnits
# bacnet_point Baud Rate 38400.0 noUnits
# bacnet_point EVE_IND_NET 0.0 noUnits
# bacnet_point HIST_COD_NET 249.0 noUnits
# bacnet_point MAIN_MOD 2.0 noUnits
# bacnet_point UM_AL_NET 0.0 noUnits
# bacnet_point UM_WN_NET 249.0 noUnits
# bacnet_point UNIT_MOD 11.0 noUnits
# bacnet_point Boiler Blocking Code 0.0 noUnits
# bacnet_point Boiler Lockout Code 32767.0 noUnits
# bacnet_point Boiler Status Code 34.0 noUnits
# bacnet_point Discrete Inputs 1 - 16 574.0 noUnits
# bacnet_point Discrete Inputs 17 - 32 0.0 noUnits
# bacnet_point Discrete Inputs 33 - 48 64.0 noUnits
# bacnet_point Coils 16.0 noUnits
# bacnet_point Configuration 68.0 noUnits
#
# Cluster 20
# bacnet_point Current Limit 69.89999389648438 amperes
# bacnet_point Current Limit 48.19999694824219 amperes
# bacnet_point Current Limit 60.79999923706055 amperes
# bacnet_point Current Limit 4.829999923706055 amperes
# bacnet_point CURRENT 8.835749626159668 amperes
# bacnet_point Current Limit 35.39999771118164 amperes
# bacnet_point Current Limit 35.39999771118164 amperes
# bacnet_point Current Limit 69.0 amperes
# bacnet_point CHWP-P10-AMPS 0.0 amperes
# bacnet_point CHWP-P11-AMPS 30.439495086669922 amperes
# bacnet_point CHWP-P11-AMPS 40.183082580566406 amperes
# bacnet_point CHWP-P8-AMPS 0.0 amperes
# bacnet_point CHWP-P8-AMPS 14.377259254455566 amperes
# bacnet_point CHWP-P9-AMPS 0.0 amperes
# bacnet_point CHWP-P9-AMPS 14.413888931274414 amperes
# bacnet_point CWP-P1-AMPS 0.0 amperes
# bacnet_point CWP-P2-AMPS 24.285661697387695 amperes
# bacnet_point CWP-P2-AMPS 64.43213653564453 amperes
# bacnet_point CWP-P3-AMPS 28.021921157836914 amperes
# bacnet_point CWP-P3-AMPS 60.40283966064453 amperes
# bacnet_point CWP-P4-AMPS 0.0 amperes
# bacnet_point CWP-P4-AMPS 18.1135196685791 amperes
# bacnet_point CWP-P5-AMPS 0.0 amperes
# bacnet_point CWP-P5-AMPS 20.970657348632812 amperes
# bacnet_point CWP-P6-AMPS 51.75815963745117 amperes
# bacnet_point CWP-P7-AMPS 48.60797882080078 amperes
# bacnet_point CWP-P7-AMPS 48.681243896484375 amperes
# bacnet_point Current 8.699999809265137 amperes
# bacnet_point Cmpr1Curr 0.10000000149011612 amperes
# bacnet_point Cmpr2Curr 0.30000001192092896 amperes
# bacnet_point RtnFanCurr 13.100000381469727 amperes
# bacnet_point SplyFanCurr 5.900000095367432 amperes
# bacnet_point Current 0.0 amperes
# bacnet_point PUMP-P14-AMPS 0.0 amperes
# bacnet_point PUMP-P15-AMPS 0.0 amperes
# bacnet_point PUMP-P16-AMPS 0.0 amperes
# bacnet_point PUMP-P17-AMPS 0.0 amperes
# bacnet_point AHU01-RF-AMPS 2.3717844486236572 amperes
# bacnet_point AHU01-SF-AMPS 0.0 amperes
# bacnet_point AHU01-SF-AMPS 4.60621452331543 amperes
# bacnet_point AHU02-RF-AMPS 0.10072499513626099 amperes
# bacnet_point AHU02-SF-AMPS 2.6465096473693848 amperes
# bacnet_point AHU02-SF-AMPS 2.7563998699188232 amperes
# bacnet_point AHU03-RF-AMPS 0.0 amperes
# bacnet_point AHU03-SF-AMPS 5.045775413513184 amperes
# bacnet_point AHU03-SF-AMPS 6.089730262756348 amperes
# bacnet_point AHU05-RF-AMPS 0.6135445833206177 amperes
# bacnet_point AHU05-SF-AMPS 1.1446800231933594 amperes
# bacnet_point AHU05-SF-AMPS 1.2728852033615112 amperes
# bacnet_point AHU06-RF-AMPS 1.3095152378082275 amperes
# bacnet_point AHU06-SF-AMPS 7.921230316162109 amperes
# bacnet_point AHU06-SF-AMPS 8.250900268554688 amperes
# bacnet_point AHU07-RF-AMPS 0.0 amperes
# bacnet_point AHU07-SF-AMPS 15.01008129119873 amperes
# bacnet_point AHU07-SF-AMPS 9.55599594116211 amperes
# bacnet_point Current Limit 14.0 amperes
# bacnet_point Current Limit 28.399999618530273 amperes
# bacnet_point Current Limit 28.399999618530273 amperes
# bacnet_point Current Limit 6.699999809265137 amperes
# bacnet_point CURRENT 4.939199924468994 amperes
# bacnet_point CURRENT 15.514100074768066 amperes
# bacnet_point CURRENT 0.0 amperes
# bacnet_point CURRENT 3.42615008354187 amperes
# bacnet_point Current Limit 3.3299999237060547 amperes
# bacnet_point Current Limit 4.829999923706055 amperes
# bacnet_point CURRENT 8.488149642944336 amperes
# bacnet_point Current Limit 4.849999904632568 amperes
#
# Cluster 129
# bacnet_point DC Link Voltage 0.0 volts
# bacnet_point Motor Current 0.0 amperes
# bacnet_point Motor Speed 0.0 revolutionsPerMinute
# bacnet_point Motor Voltage 0.0 volts
# bacnet_point DC Link Voltage 624.0 volts
# bacnet_point Motor Current 40.29999923706055 amperes
# bacnet_point Motor Speed 1767.0 revolutionsPerMinute
# bacnet_point Motor Voltage 456.79998779296875 volts
# bacnet_point Mode 1 Volume Total 592974016.0 usGallons
# bacnet_point Mode 2 Volume Total 0.0 usGallons
# bacnet_point Mode 1 Volume Total 6310240768.0 usGallons
# bacnet_point Mode 2 Volume Total 0.0 usGallons
# bacnet_point Mode 1 Volume Total 644288000.0 usGallons
# bacnet_point Mode 2 Volume Total 0.0 usGallons
# bacnet_point DC Link Voltage 657.0 volts
# bacnet_point Motor Current 28.599998474121094 amperes
# bacnet_point Motor Speed 896.0 revolutionsPerMinute
# bacnet_point Motor Voltage 230.0 volts
# bacnet_point DC Link Voltage 699.0 volts
# bacnet_point Motor Current 0.019999999552965164 amperes
# bacnet_point Motor Speed 600.0 revolutionsPerMinute
# bacnet_point Motor Voltage 153.39999389648438 volts
# bacnet_point DC BUS VOLT 629.0603637695312 volts
# bacnet_point OUTPUT SPEED 1226.0 revolutionsPerMinute
# bacnet_point OUTPUT VOLT 352.990966796875 volts
# bacnet_point DC Link Voltage 669.0 volts
# bacnet_point Motor Current 0.0 amperes
# bacnet_point Motor Speed 0.0 revolutionsPerMinute
# bacnet_point Motor Voltage 0.0 volts
# bacnet_point DC Link Voltage 646.0 volts
# bacnet_point Motor Current 0.0 amperes
# bacnet_point Motor Speed 0.0 revolutionsPerMinute
# bacnet_point Motor Voltage 0.0 volts
# bacnet_point DC Link Voltage 610.0 volts
# bacnet_point Motor Current 49.19999694824219 amperes
# bacnet_point Motor Speed 1780.0 revolutionsPerMinute
# bacnet_point Motor Voltage 460.0 volts
# bacnet_point Voltage 47.20000076293945 volts
# bacnet_point Voltage 0.0 volts
# bacnet_point DC Link Voltage 661.0 volts
# bacnet_point Motor Current 0.0 amperes
# bacnet_point Motor Speed 0.0 revolutionsPerMinute
# bacnet_point Motor Voltage 0.0 volts
# bacnet_point DC Link Voltage 647.0 volts
# bacnet_point Motor Current 18.5 amperes
# bacnet_point Motor Speed 1459.0 revolutionsPerMinute
# bacnet_point Motor Voltage 377.29998779296875 volts
# bacnet_point DC Link Voltage 663.0 volts
# bacnet_point Motor Current 0.0 amperes
# bacnet_point Motor Speed 0.0 revolutionsPerMinute
# bacnet_point Motor Voltage 0.0 volts
# bacnet_point DC Link Voltage 660.0 volts
# bacnet_point Motor Current 3.309999942779541 amperes
# bacnet_point Motor Speed 595.0 revolutionsPerMinute
# bacnet_point Motor Voltage 153.09999084472656 volts
# bacnet_point Mode 1 Volume Total 852076992.0 usGallons
# bacnet_point Mode 2 Volume Total 0.0 usGallons
# bacnet_point DC BUS VOLT 653.4942626953125 volts
# bacnet_point OUTPUT SPEED 1800.0 revolutionsPerMinute
# bacnet_point OUTPUT VOLT 615.4293823242188 volts
# bacnet_point DC BUS VOLT 646.4807739257812 volts
# bacnet_point OUTPUT SPEED 1155.0 revolutionsPerMinute
# bacnet_point OUTPUT VOLT 325.10687255859375 volts
# bacnet_point DC BUS VOLT 657.34033203125 volts
# bacnet_point OUTPUT SPEED 0.0 revolutionsPerMinute
# bacnet_point OUTPUT VOLT 0.0 volts
# bacnet_point CUMD_AO 10.0 volts
# bacnet_point EFANMD_AO 0.0 volts
# bacnet_point FBDMD_AO 0.0 volts
# bacnet_point ODMD_AO 3.0 volts
# bacnet_point SFANMD_AO 10.0 volts
# bacnet_point WHEMD_AO 10.0 volts
# bacnet_point DC BUS VOLT 639.1845703125 volts
# bacnet_point OUTPUT SPEED 1146.0 revolutionsPerMinute
# bacnet_point OUTPUT VOLT 323.8059997558594 volts
# bacnet_point DC Link Voltage 689.0 volts
# bacnet_point Motor Current 1.659999966621399 amperes
# bacnet_point Motor Speed 593.0 revolutionsPerMinute
# bacnet_point Motor Voltage 153.0 volts
# bacnet_point DC Link Voltage 673.0 volts
# bacnet_point Motor Current 1.7299998998641968 amperes
# bacnet_point Motor Speed 836.0 revolutionsPerMinute
# bacnet_point Motor Voltage 214.59999084472656 volts
# bacnet_point DC BUS VOLT 644.6708984375 volts
# bacnet_point OUTPUT SPEED 759.0 revolutionsPerMinute
# bacnet_point OUTPUT VOLT 185.5733642578125 volts
# bacnet_point DC Link Voltage 657.0 volts
# bacnet_point Motor Current 2.3499999046325684 amperes
# bacnet_point Motor Speed 772.0 revolutionsPerMinute
# bacnet_point Motor Voltage 199.1999969482422 volts
# bacnet_point CUMD_AO 2.200000047683716 volts
# bacnet_point EFANMD_AO 0.0 volts
# bacnet_point FBDMD_AO 10.0 volts
# bacnet_point ODMD_AO 3.700000047683716 volts
# bacnet_point SFANMD_AO 10.0 volts
# bacnet_point WHEMD_AO 10.0 volts
#
# Cluster 85
# bacnet_point FBFixedControlWord PDI 0 0.0 noUnits
# bacnet_point FBFixedStatusWord PDO 0 64.0 noUnits
# bacnet_point FBGeneralControlWord PDI 1 0.0 noUnits
# bacnet_point FBGeneralStatusWord PDO 1 17.0 noUnits
# bacnet_point FBFixedControlWord PDI 0 0.0 noUnits
# bacnet_point FBFixedStatusWord PDO 0 163.0 noUnits
# bacnet_point FBGeneralControlWord PDI 1 0.0 noUnits
# bacnet_point FBGeneralStatusWord PDO 1 17.0 noUnits
# bacnet_point FBFixedControlWord PDI 0 0.0 noUnits
# bacnet_point FBFixedStatusWord PDO 0 163.0 noUnits
# bacnet_point FBGeneralControlWord PDI 1 0.0 noUnits
# bacnet_point FBGeneralStatusWord PDO 1 17.0 noUnits
# bacnet_point FBFixedControlWord PDI 0 1.0 noUnits
# bacnet_point FBFixedStatusWord PDO 0 163.0 noUnits
# bacnet_point FBGeneralControlWord PDI 1 0.0 noUnits
# bacnet_point FBGeneralStatusWord PDO 1 17.0 noUnits
# bacnet_point FBFixedControlWord PDI 0 0.0 noUnits
# bacnet_point FBFixedStatusWord PDO 0 65.0 noUnits
# bacnet_point FBGeneralControlWord PDI 1 0.0 noUnits
# bacnet_point FBGeneralStatusWord PDO 1 17.0 noUnits
# bacnet_point FBFixedControlWord PDI 0 0.0 noUnits
# bacnet_point FBFixedStatusWord PDO 0 65.0 noUnits
# bacnet_point FBGeneralControlWord PDI 1 0.0 noUnits
# bacnet_point FBGeneralStatusWord PDO 1 19.0 noUnits
# bacnet_point FBFixedControlWord PDI 0 0.0 noUnits
# bacnet_point FBFixedStatusWord PDO 0 163.0 noUnits
# bacnet_point FBGeneralControlWord PDI 1 0.0 noUnits
# bacnet_point FBGeneralStatusWord PDO 1 17.0 noUnits
# bacnet_point FBFixedControlWord PDI 0 0.0 noUnits
# bacnet_point FBFixedStatusWord PDO 0 65.0 noUnits
# bacnet_point FBGeneralControlWord PDI 1 0.0 noUnits
# bacnet_point FBGeneralStatusWord PDO 1 19.0 noUnits
# bacnet_point FBFixedControlWord PDI 0 0.0 noUnits
# bacnet_point FBFixedStatusWord PDO 0 163.0 noUnits
# bacnet_point FBGeneralControlWord PDI 1 0.0 noUnits
# bacnet_point FBGeneralStatusWord PDO 1 17.0 noUnits
# bacnet_point FBFixedControlWord PDI 0 0.0 noUnits
# bacnet_point FBFixedStatusWord PDO 0 65.0 noUnits
# bacnet_point FBGeneralControlWord PDI 1 0.0 noUnits
# bacnet_point FBGeneralStatusWord PDO 1 19.0 noUnits
# bacnet_point FBFixedControlWord PDI 0 1.0 noUnits
# bacnet_point FBFixedStatusWord PDO 0 163.0 noUnits
# bacnet_point FBGeneralControlWord PDI 1 0.0 noUnits
# bacnet_point FBGeneralStatusWord PDO 1 17.0 noUnits
# bacnet_point FBFixedControlWord PDI 0 1.0 noUnits
# bacnet_point FBFixedStatusWord PDO 0 163.0 noUnits
# bacnet_point FBGeneralControlWord PDI 1 0.0 noUnits
# bacnet_point FBGeneralStatusWord PDO 1 17.0 noUnits
# bacnet_point FBFixedControlWord PDI 0 1.0 noUnits
# bacnet_point FBFixedStatusWord PDO 0 163.0 noUnits
# bacnet_point FBGeneralControlWord PDI 1 0.0 noUnits
# bacnet_point FBGeneralStatusWord PDO 1 17.0 noUnits
# bacnet_point FBFixedControlWord PDI 0 1.0 noUnits
# bacnet_point FBFixedStatusWord PDO 0 163.0 noUnits
# bacnet_point FBGeneralControlWord PDI 1 0.0 noUnits
# bacnet_point FBGeneralStatusWord PDO 1 17.0 noUnits
#
# Cluster 77
# bacnet_point FBProcessDataIn1 0.0 noUnits
# bacnet_point FBProcessDataIn2 0.0 noUnits
# bacnet_point FBProcessDataIn3 0.0 noUnits
# bacnet_point FBProcessDataIn4 0.0 noUnits
# bacnet_point FBProcessDataOut1 0.0 noUnits
# bacnet_point FBProcessDataOut2 0.0 noUnits
# bacnet_point FBProcessDataOut3 0.0 noUnits
# bacnet_point FBProcessDataOut4 0.0 noUnits
# bacnet_point FBProcessDataOut5 0.0 noUnits
# bacnet_point FBProcessDataOut7 0.0 noUnits
# bacnet_point FBProcessDataOut8 0.0 noUnits
# bacnet_point FBProcessDataIn1 0.0 noUnits
# bacnet_point FBProcessDataIn2 0.0 noUnits
# bacnet_point FBProcessDataIn3 0.0 noUnits
# bacnet_point FBProcessDataIn4 0.0 noUnits
# bacnet_point FBProcessDataOut7 0.0 noUnits
# bacnet_point FBProcessDataOut8 0.0 noUnits
# bacnet_point FBProcessDataIn1 0.0 noUnits
# bacnet_point FBProcessDataIn2 0.0 noUnits
# bacnet_point FBProcessDataIn3 0.0 noUnits
# bacnet_point FBProcessDataIn4 0.0 noUnits
# bacnet_point FBProcessDataOut7 0.0 noUnits
# bacnet_point FBProcessDataOut8 0.0 noUnits
# bacnet_point FBProcessDataIn1 0.0 noUnits
# bacnet_point FBProcessDataIn2 0.0 noUnits
# bacnet_point FBProcessDataIn3 0.0 noUnits
# bacnet_point FBProcessDataIn4 0.0 noUnits
# bacnet_point FBProcessDataOut2 0.0 noUnits
# bacnet_point FBProcessDataOut4 1.0 noUnits
# bacnet_point FBProcessDataOut7 0.0 noUnits
# bacnet_point FBProcessDataOut8 0.0 noUnits
# bacnet_point FBProcessDataIn1 0.0 noUnits
# bacnet_point FBProcessDataIn2 0.0 noUnits
# bacnet_point FBProcessDataIn3 0.0 noUnits
# bacnet_point FBProcessDataIn4 0.0 noUnits
# bacnet_point FBProcessDataOut1 0.0 noUnits
# bacnet_point FBProcessDataOut2 0.0 noUnits
# bacnet_point FBProcessDataOut3 0.0 noUnits
# bacnet_point FBProcessDataOut4 0.0 noUnits
# bacnet_point FBProcessDataOut7 0.0 noUnits
# bacnet_point FBProcessDataOut8 0.0 noUnits
# bacnet_point FBProcessDataIn1 0.0 noUnits
# bacnet_point FBProcessDataIn2 0.0 noUnits
# bacnet_point FBProcessDataIn3 0.0 noUnits
# bacnet_point FBProcessDataIn4 0.0 noUnits
# bacnet_point FBProcessDataOut1 0.0 noUnits
# bacnet_point FBProcessDataOut2 0.0 noUnits
# bacnet_point FBProcessDataOut3 0.0 noUnits
# bacnet_point FBProcessDataOut4 0.0 noUnits
# bacnet_point FBProcessDataOut7 0.0 noUnits
# bacnet_point FBProcessDataOut8 0.0 noUnits
# bacnet_point FBProcessDataIn1 0.0 noUnits
# bacnet_point FBProcessDataIn2 0.0 noUnits
# bacnet_point FBProcessDataIn3 0.0 noUnits
# bacnet_point FBProcessDataIn4 0.0 noUnits
# bacnet_point FBProcessDataOut7 0.0 noUnits
# bacnet_point FBProcessDataOut8 0.0 noUnits
# bacnet_point FBProcessDataIn1 0.0 noUnits
# bacnet_point FBProcessDataIn2 0.0 noUnits
# bacnet_point FBProcessDataIn3 0.0 noUnits
# bacnet_point FBProcessDataIn4 0.0 noUnits
# bacnet_point FBProcessDataOut1 0.0 noUnits
# bacnet_point FBProcessDataOut2 0.0 noUnits
# bacnet_point FBProcessDataOut3 0.0 noUnits
# bacnet_point FBProcessDataOut4 0.0 noUnits
# bacnet_point FBProcessDataOut7 0.0 noUnits
# bacnet_point FBProcessDataOut8 0.0 noUnits
# bacnet_point FBProcessDataIn1 0.0 noUnits
# bacnet_point FBProcessDataIn2 0.0 noUnits
# bacnet_point FBProcessDataIn3 0.0 noUnits
# bacnet_point FBProcessDataIn4 0.0 noUnits
# bacnet_point FBProcessDataOut7 0.0 noUnits
# bacnet_point FBProcessDataOut8 0.0 noUnits
# bacnet_point FBProcessDataIn1 0.0 noUnits
# bacnet_point FBProcessDataIn2 0.0 noUnits
# bacnet_point FBProcessDataIn3 0.0 noUnits
# bacnet_point FBProcessDataIn4 0.0 noUnits
# bacnet_point FBProcessDataOut1 0.0 noUnits
# bacnet_point FBProcessDataOut2 0.0 noUnits
# bacnet_point FBProcessDataOut3 0.0 noUnits
# bacnet_point FBProcessDataOut4 0.0 noUnits
# bacnet_point FBProcessDataOut7 0.0 noUnits
# bacnet_point FBProcessDataOut8 0.0 noUnits
# bacnet_point FBProcessDataIn1 0.0 noUnits
# bacnet_point FBProcessDataIn2 0.0 noUnits
# bacnet_point FBProcessDataIn3 0.0 noUnits
# bacnet_point FBProcessDataIn4 0.0 noUnits
# bacnet_point FBProcessDataOut7 0.0 noUnits
# bacnet_point FBProcessDataOut8 0.0 noUnits
# bacnet_point FBProcessDataIn1 0.0 noUnits
# bacnet_point FBProcessDataIn2 0.0 noUnits
# bacnet_point FBProcessDataIn3 0.0 noUnits
# bacnet_point FBProcessDataIn4 0.0 noUnits
# bacnet_point FBProcessDataOut7 0.0 noUnits
# bacnet_point FBProcessDataOut8 0.0 noUnits
# bacnet_point FBProcessDataIn1 0.0 noUnits
# bacnet_point FBProcessDataIn2 0.0 noUnits
# bacnet_point FBProcessDataIn3 0.0 noUnits
# bacnet_point FBProcessDataIn4 0.0 noUnits
# bacnet_point FBProcessDataOut7 0.0 noUnits
# bacnet_point FBProcessDataOut8 0.0 noUnits
# bacnet_point FBProcessDataIn1 0.0 noUnits
# bacnet_point FBProcessDataIn2 0.0 noUnits
# bacnet_point FBProcessDataIn3 0.0 noUnits
# bacnet_point FBProcessDataIn4 0.0 noUnits
# bacnet_point FBProcessDataOut7 0.0 noUnits
# bacnet_point FBProcessDataOut8 0.0 noUnits
#
# Cluster 33
# bacnet_point FBProcessDataOut6 2050.0 noUnits
# bacnet_point FBProcessDataOut1 992.0 noUnits
# bacnet_point FBProcessDataOut2 402.0 noUnits
# bacnet_point FBProcessDataOut3 4567.0 noUnits
# bacnet_point FBProcessDataOut4 770.0 noUnits
# bacnet_point FBProcessDataOut5 624.0 noUnits
# bacnet_point FBProcessDataOut6 10247.0 noUnits
# bacnet_point FBProcessDataOut1 500.0 noUnits
# bacnet_point FBProcessDataOut2 293.0 noUnits
# bacnet_point FBProcessDataOut3 2302.0 noUnits
# bacnet_point FBProcessDataOut4 132.0 noUnits
# bacnet_point FBProcessDataOut5 658.0 noUnits
# bacnet_point FBProcessDataOut6 10247.0 noUnits
# bacnet_point FBProcessDataOut1 333.0 noUnits
# bacnet_point FBProcessDataOut3 1532.0 noUnits
# bacnet_point FBProcessDataOut5 700.0 noUnits
# bacnet_point FBProcessDataOut6 10247.0 noUnits
# bacnet_point FBProcessDataOut5 668.0 noUnits
# bacnet_point FBProcessDataOut6 2051.0 noUnits
# bacnet_point FBProcessDataOut5 646.0 noUnits
# bacnet_point FBProcessDataOut6 -6141.0 noUnits
# bacnet_point FBProcessDataOut1 999.0 noUnits
# bacnet_point FBProcessDataOut2 498.0 noUnits
# bacnet_point FBProcessDataOut3 4600.0 noUnits
# bacnet_point FBProcessDataOut4 774.0 noUnits
# bacnet_point FBProcessDataOut5 610.0 noUnits
# bacnet_point FBProcessDataOut6 10247.0 noUnits
# bacnet_point FBProcessDataOut5 661.0 noUnits
# bacnet_point FBProcessDataOut6 18435.0 noUnits
# bacnet_point FBProcessDataOut1 821.0 noUnits
# bacnet_point FBProcessDataOut2 186.0 noUnits
# bacnet_point FBProcessDataOut3 3777.0 noUnits
# bacnet_point FBProcessDataOut4 503.0 noUnits
# bacnet_point FBProcessDataOut5 647.0 noUnits
# bacnet_point FBProcessDataOut6 10247.0 noUnits
# bacnet_point FBProcessDataOut5 663.0 noUnits
# bacnet_point FBProcessDataOut6 18435.0 noUnits
# bacnet_point FBProcessDataOut1 333.0 noUnits
# bacnet_point FBProcessDataOut2 33.0 noUnits
# bacnet_point FBProcessDataOut3 1532.0 noUnits
# bacnet_point FBProcessDataOut4 23.0 noUnits
# bacnet_point FBProcessDataOut5 660.0 noUnits
# bacnet_point FBProcessDataOut6 10247.0 noUnits
# bacnet_point FBProcessDataOut1 333.0 noUnits
# bacnet_point FBProcessDataOut2 16.0 noUnits
# bacnet_point FBProcessDataOut3 1534.0 noUnits
# bacnet_point FBProcessDataOut4 48.0 noUnits
# bacnet_point FBProcessDataOut5 690.0 noUnits
# bacnet_point FBProcessDataOut6 10247.0 noUnits
# bacnet_point FBProcessDataOut1 466.0 noUnits
# bacnet_point FBProcessDataOut2 17.0 noUnits
# bacnet_point FBProcessDataOut3 2145.0 noUnits
# bacnet_point FBProcessDataOut4 58.0 noUnits
# bacnet_point FBProcessDataOut5 672.0 noUnits
# bacnet_point FBProcessDataOut6 10247.0 noUnits
# bacnet_point FBProcessDataOut1 433.0 noUnits
# bacnet_point FBProcessDataOut2 23.0 noUnits
# bacnet_point FBProcessDataOut3 1991.0 noUnits
# bacnet_point FBProcessDataOut4 68.0 noUnits
# bacnet_point FBProcessDataOut5 658.0 noUnits
# bacnet_point FBProcessDataOut6 10247.0 noUnits
#
# Cluster 58
# bacnet_point Frequency Setpoint 60.0 hertz
# bacnet_point Max Frequency 60.0 hertz
# bacnet_point Min Frequency 20.0 hertz
# bacnet_point Output Frequency 0.0 hertz
# bacnet_point Frequency Setpoint 59.55999755859375 hertz
# bacnet_point Max Frequency 60.0 hertz
# bacnet_point Min Frequency 22.689998626708984 hertz
# bacnet_point Output Frequency 59.55999755859375 hertz
# bacnet_point Frequency Setpoint 30.03999900817871 hertz
# bacnet_point Max Frequency 60.0 hertz
# bacnet_point Min Frequency 20.0 hertz
# bacnet_point Output Frequency 30.03999900817871 hertz
# bacnet_point Frequency Setpoint 20.0 hertz
# bacnet_point Max Frequency 60.0 hertz
# bacnet_point Min Frequency 20.0 hertz
# bacnet_point Output Frequency 20.0 hertz
# bacnet_point OUTPUT FREQ 40.86000061035156 hertz
# bacnet_point Frequency Setpoint 20.0 hertz
# bacnet_point Max Frequency 60.0 hertz
# bacnet_point Min Frequency 20.0 hertz
# bacnet_point Output Frequency 0.0 hertz
# bacnet_point Frequency Setpoint 20.0 hertz
# bacnet_point Max Frequency 60.0 hertz
# bacnet_point Min Frequency 20.0 hertz
# bacnet_point Output Frequency 0.0 hertz
# bacnet_point Frequency Setpoint 60.0 hertz
# bacnet_point Max Frequency 60.0 hertz
# bacnet_point Min Frequency 20.0 hertz
# bacnet_point Output Frequency 60.0 hertz
# bacnet_point Frequency Setpoint 20.0 hertz
# bacnet_point Max Frequency 60.0 hertz
# bacnet_point Min Frequency 20.0 hertz
# bacnet_point Output Frequency 0.0 hertz
# bacnet_point Frequency Setpoint 49.25 hertz
# bacnet_point Max Frequency 60.0 hertz
# bacnet_point Min Frequency 20.0 hertz
# bacnet_point Output Frequency 49.25 hertz
# bacnet_point Frequency Setpoint 20.0 hertz
# bacnet_point Max Frequency 60.0 hertz
# bacnet_point Min Frequency 20.0 hertz
# bacnet_point Output Frequency 0.0 hertz
# bacnet_point Frequency Setpoint 20.0 hertz
# bacnet_point Max Frequency 60.0 hertz
# bacnet_point Min Frequency 20.0 hertz
# bacnet_point Output Frequency 20.0 hertz
# bacnet_point OUTPUT FREQ 60.0 hertz
# bacnet_point OUTPUT FREQ 38.5 hertz
# bacnet_point OUTPUT FREQ 0.0 hertz
# bacnet_point OUTPUT FREQ 38.20000076293945 hertz
# bacnet_point Frequency Setpoint 20.0 hertz
# bacnet_point Max Frequency 60.0 hertz
# bacnet_point Min Frequency 20.0 hertz
# bacnet_point Output Frequency 20.0 hertz
# bacnet_point Frequency Setpoint 28.0 hertz
# bacnet_point Max Frequency 60.0 hertz
# bacnet_point Min Frequency 28.0 hertz
# bacnet_point Output Frequency 28.0 hertz
# bacnet_point OUTPUT FREQ 25.299999237060547 hertz
# bacnet_point Frequency Setpoint 26.0 hertz
# bacnet_point Max Frequency 60.0 hertz
# bacnet_point Min Frequency 26.0 hertz
# bacnet_point Output Frequency 26.0 hertz
#
# Cluster 141
# bacnet_point Kilowatt Hours 303030.0 kilowattHours
# bacnet_point Kilowatt Hours Total 303030.0 kilowattHours
# bacnet_point Kilowatt Hours 310500.0 kilowattHours
# bacnet_point Kilowatt Hours Total 310500.0 kilowattHours
# bacnet_point Mode 1 Energy Total 10355000320.0 btus
# bacnet_point Energy Rate 2110052.25 btusPerHour
# bacnet_point Mode 1 Energy Total 63979999232.0 btus
# bacnet_point Energy Rate 538531.0 btusPerHour
# bacnet_point Mode 1 Energy Total 16587299840.0 btus
# bacnet_point Kilowatt Hours 1153800.125 kilowattHours
# bacnet_point Kilowatt Hours Total 1153800.125 kilowattHours
# bacnet_point Kilowatt Hours 2963.0 kilowattHours
# bacnet_point Kilowatt Hours Total 2963.0 kilowattHours
# bacnet_point KWH (R) 300649.0 kilowattHours
# bacnet_point Kilowatt Hours 226750.0 kilowattHours
# bacnet_point Kilowatt Hours Total 226750.0 kilowattHours
# bacnet_point Kilowatt Hours 195160.0 kilowattHours
# bacnet_point Kilowatt Hours Total 195160.0 kilowattHours
# bacnet_point Kilowatt Hours 1298700.125 kilowattHours
# bacnet_point Kilowatt Hours Total 1298700.125 kilowattHours
# bacnet_point GEO-TOTAL-BTU 2029063.625 btus
# bacnet_point GEO-TOTAL-BTU 728061.875 btus
# bacnet_point Kilowatts 6.199999809265137 kilowatts
# bacnet_point LIGHT-COUNT-CURRENT 8574411.0 kilowattHours
# bacnet_point LIGHT-COUNT-CURRENT 8596412.0 kilowattHours
# bacnet_point LIGHT-COUNT-DAY 68.0 kilowattHours
# bacnet_point LIGHT-COUNT-DAY 75.0 kilowattHours
# bacnet_point LIGHT-COUNT-HOUR 0.0 kilowattHours
# bacnet_point LIGHT-COUNT-HOUR 16.0 kilowattHours
# bacnet_point LIGHT-COUNT-MONTH 934.0 kilowattHours
# bacnet_point LIGHT-COUNT-MONTH 9616.0 kilowattHours
# bacnet_point LIGHT-COUNT-QUARTER 2.0 kilowattHours
# bacnet_point LIGHT-COUNT-QUARTER 8.0 kilowattHours
# bacnet_point LIGHT-COUNT-SEASON 21308.0 kilowattHours
# bacnet_point LIGHT-COUNT-SEASON 7636.0 kilowattHours
# bacnet_point LIGHT-COUNT-WEEK 516.0 kilowattHours
# bacnet_point LIGHT-COUNT-WEEK 852.0 kilowattHours
# bacnet_point LIGHT-COUNT-YEAR 9107108.0 kilowattHours
# bacnet_point MECH-COUNT-CURRENT 48157992.0 kilowattHours
# bacnet_point MECH-COUNT-CURRENT 48173372.0 kilowattHours
# bacnet_point MECH-COUNT-DAY 0.0 kilowattHours
# bacnet_point MECH-COUNT-DAY 40.0 kilowattHours
# bacnet_point MECH-COUNT-HOUR 0.0 kilowattHours
# bacnet_point MECH-COUNT-MONTH 50606068.0 kilowattHours
# bacnet_point MECH-COUNT-MONTH 50621660.0 kilowattHours
# bacnet_point MECH-COUNT-QUARTER 0.0 kilowattHours
# bacnet_point MECH-COUNT-QUARTER 4.0 kilowattHours
# bacnet_point MECH-COUNT-SEASON 0.0 kilowattHours
# bacnet_point MECH-COUNT-WEEK 240.0 kilowattHours
# bacnet_point MECH-COUNT-WEEK 416.0 kilowattHours
# bacnet_point MECH-COUNT-YEAR 0.0 kilowattHours
# bacnet_point MISC-COUNT-CURRENT 31746448.0 kilowattHours
# bacnet_point MISC-COUNT-CURRENT 31821692.0 kilowattHours
# bacnet_point MISC-COUNT-DAY 344.0 kilowattHours
# bacnet_point MISC-COUNT-DAY 374.0 kilowattHours
# bacnet_point MISC-COUNT-HOUR 0.0 kilowattHours
# bacnet_point MISC-COUNT-HOUR 16.0 kilowattHours
# bacnet_point MISC-COUNT-MONTH 33229224.0 kilowattHours
# bacnet_point MISC-COUNT-MONTH 33305722.0 kilowattHours
# bacnet_point MISC-COUNT-QUARTER 0.0 kilowattHours
# bacnet_point MISC-COUNT-QUARTER 14.0 kilowattHours
# bacnet_point MISC-COUNT-SEASON 0.0 kilowattHours
# bacnet_point MISC-COUNT-WEEK 2016.0 kilowattHours
# bacnet_point MISC-COUNT-WEEK 3298.0 kilowattHours
# bacnet_point MISC-COUNT-YEAR 0.0 kilowattHours
# bacnet_point SOLAR-DOLLARS 570353.4375 1031
# bacnet_point SOLAR-DOLLARS 589445.6875 1031
# bacnet_point SOLAR-IRRADIANCE 190.0 1035
# bacnet_point SOLAR-IRRADIANCE 358.1000061035156 1035
# bacnet_point SOLAR-KWHNet-Total 4421344.5 kilowattHours
# bacnet_point SOLAR-KWHNet-Total 4569346.5 kilowattHours
# bacnet_point SOLAR-REAL-TIME-KW 129.60000610351562 kilowatts
# bacnet_point SOLAR-REAL-TIME-KW 67.20000457763672 kilowatts
# bacnet_point TOTAL-COUNT-CURRENT 92609024.0 kilowattHours
# bacnet_point TOTAL-COUNT-CURRENT 92721648.0 kilowattHours
# bacnet_point TOTAL-COUNT-DAY 440.0 kilowattHours
# bacnet_point TOTAL-COUNT-DAY 456.0 kilowattHours
# bacnet_point TOTAL-COUNT-HOUR 0.0 kilowattHours
# bacnet_point TOTAL-COUNT-HOUR 32.0 kilowattHours
# bacnet_point TOTAL-COUNT-MONTH 97025640.0 kilowattHours
# bacnet_point TOTAL-COUNT-MONTH 97140088.0 kilowattHours
# bacnet_point TOTAL-COUNT-QUARTER 0.0 kilowattHours
# bacnet_point TOTAL-COUNT-QUARTER 24.0 kilowattHours
# bacnet_point TOTAL-COUNT-SEASON 0.0 kilowattHours
# bacnet_point TOTAL-COUNT-WEEK 2768.0 kilowattHours
# bacnet_point TOTAL-COUNT-WEEK 4568.0 kilowattHours
# bacnet_point TOTAL-COUNT-YEAR 0.0 kilowattHours
# bacnet_point Kilowatt Hours 5311.0 kilowattHours
# bacnet_point Kilowatt Hours Total 5311.0 kilowattHours
# bacnet_point Kilowatt Hours 206710.0 kilowattHours
# bacnet_point Kilowatt Hours Total 206710.0 kilowattHours
# bacnet_point Kilowatt Hours 1528.5999755859375 kilowattHours
# bacnet_point Kilowatt Hours Total 1528.5999755859375 kilowattHours
# bacnet_point Kilowatt Hours 9602.0 kilowattHours
# bacnet_point Kilowatt Hours Total 9602.0 kilowattHours
# bacnet_point Mode 1 Energy Total 21710200832.0 btus
# bacnet_point KWH (R) 145684.0 kilowattHours
# bacnet_point KWH (R) 404570.0 kilowattHours
# bacnet_point KWH (R) 80.0 kilowattHours
# bacnet_point KWH (R) 62473.0 kilowattHours
# bacnet_point Kilowatt Hours 5035.0 kilowattHours
# bacnet_point Kilowatt Hours Total 5035.0 kilowattHours
# bacnet_point Kilowatt Hours 6875.0 kilowattHours
# bacnet_point Kilowatt Hours Total 6875.0 kilowattHours
# bacnet_point KWH (R) 213129.0 kilowattHours
# bacnet_point Kilowatt Hours 11939.0 kilowattHours
# bacnet_point Kilowatt Hours Total 11939.0 kilowattHours
#
# Cluster 104
# bacnet_point Load (Power) 0.0 percent
# bacnet_point Motor Temp Rise 0.0 percent
# bacnet_point Motor Torque 0.0 percent
# bacnet_point Speed Reference 0.0 percent
# bacnet_point Torque Reference 0.0 percent
# bacnet_point Load (Power) 77.19999694824219 percent
# bacnet_point Motor Temp Rise 71.0999984741211 percent
# bacnet_point Motor Torque 78.0999984741211 percent
# bacnet_point Speed Reference 0.0 percent
# bacnet_point Torque Reference 0.0 percent
# bacnet_point Load (Power) 12.899999618530273 percent
# bacnet_point Motor Temp Rise 33.099998474121094 percent
# bacnet_point Motor Torque 26.0 percent
# bacnet_point Speed Reference 0.0 percent
# bacnet_point Torque Reference 0.0 percent
# bacnet_point Load (Power) 0.0 percent
# bacnet_point Motor Temp Rise 0.19999998807907104 percent
# bacnet_point Motor Torque 0.5 percent
# bacnet_point Speed Reference 0.0 percent
# bacnet_point Torque Reference 0.0 percent
# bacnet_point DRIVE TEMP 0.0 percent
# bacnet_point POWER 20.070383071899414 percent
# bacnet_point PRC PID FBCK 0.0 percent
# bacnet_point TORQUE 31.5 percent
# bacnet_point Load (Power) 0.0 percent
# bacnet_point Motor Temp Rise 0.5999999642372131 percent
# bacnet_point Motor Torque 0.0 percent
# bacnet_point Speed Reference 0.0 percent
# bacnet_point Torque Reference 0.0 percent
# bacnet_point Load (Power) 0.0 percent
# bacnet_point Motor Temp Rise 0.0 percent
# bacnet_point Motor Torque 0.0 percent
# bacnet_point Speed Reference 0.0 percent
# bacnet_point Torque Reference 0.0 percent
# bacnet_point Load (Power) 77.5 percent
# bacnet_point Motor Temp Rise 69.0999984741211 percent
# bacnet_point Motor Torque 76.79999542236328 percent
# bacnet_point Speed Reference 0.0 percent
# bacnet_point Torque Reference 0.0 percent
# bacnet_point CompMotorCurrentPercent 63.0 percent
# bacnet_point PowerFactor 0.0 powerFactor
# bacnet_point CompMotorCurrentPercent 0.0 percent
# bacnet_point PowerFactor 0.0 powerFactor
# bacnet_point LIGHTING-KW-MONTH% 0.0 percent
# bacnet_point Load (Power) 0.0 percent
# bacnet_point Motor Temp Rise 0.5999999642372131 percent
# bacnet_point Motor Torque 0.0 percent
# bacnet_point Speed Reference 0.0 percent
# bacnet_point Torque Reference 0.0 percent
# bacnet_point Load (Power) 50.69999694824219 percent
# bacnet_point Motor Temp Rise 60.599998474121094 percent
# bacnet_point Motor Torque 61.29999923706055 percent
# bacnet_point Speed Reference 0.0 percent
# bacnet_point Torque Reference 0.0 percent
# bacnet_point Load (Power) 0.0 percent
# bacnet_point Motor Temp Rise 0.0 percent
# bacnet_point Motor Torque 0.0 percent
# bacnet_point Speed Reference 0.0 percent
# bacnet_point Torque Reference 0.0 percent
# bacnet_point Load (Power) 2.5 percent
# bacnet_point Motor Temp Rise 51.599998474121094 percent
# bacnet_point Motor Torque 8.09999942779541 percent
# bacnet_point Speed Reference 0.0 percent
# bacnet_point Torque Reference 0.0 percent
# bacnet_point DRIVE TEMP 0.0 percent
# bacnet_point POWER 0.6186076998710632 percent
# bacnet_point PRC PID FBCK 0.0 percent
# bacnet_point TORQUE 0.14999999105930328 percent
# bacnet_point DRIVE TEMP 0.0 percent
# bacnet_point POWER 19.410064697265625 percent
# bacnet_point PRC PID FBCK 0.0 percent
# bacnet_point TORQUE 36.18000030517578 percent
# bacnet_point DRIVE TEMP 0.0 percent
# bacnet_point POWER 0.0 percent
# bacnet_point PRC PID FBCK 0.0 percent
# bacnet_point TORQUE 0.0 percent
# bacnet_point DRIVE TEMP 0.0 percent
# bacnet_point POWER 19.46427345275879 percent
# bacnet_point PRC PID FBCK 0.0 percent
# bacnet_point TORQUE 33.61000061035156 percent
# bacnet_point Load (Power) 5.0 percent
# bacnet_point Motor Temp Rise 71.19999694824219 percent
# bacnet_point Motor Torque 15.0 percent
# bacnet_point Speed Reference 0.0 percent
# bacnet_point Torque Reference 0.0 percent
# bacnet_point Load (Power) 5.399999618530273 percent
# bacnet_point Motor Temp Rise 26.899999618530273 percent
# bacnet_point Motor Torque 10.899999618530273 percent
# bacnet_point Speed Reference 10.0 percent
# bacnet_point Torque Reference 0.0 percent
# bacnet_point DRIVE TEMP 0.0 percent
# bacnet_point POWER 8.353398323059082 percent
# bacnet_point PRC PID FBCK 0.0 percent
# bacnet_point TORQUE 21.760000228881836 percent
# bacnet_point Load (Power) 7.199999809265137 percent
# bacnet_point Motor Temp Rise 51.89999771118164 percent
# bacnet_point Motor Torque 15.699999809265137 percent
# bacnet_point Speed Reference 0.0 percent
# bacnet_point Torque Reference 0.0 percent
# bacnet_point Boiler Pump Speed 0.0 percent
# bacnet_point Cascade Current Power 0.0 percent
# bacnet_point Cascade Total Power 0.0 percent
# bacnet_point Firing Rate 0.0 percent
# bacnet_point System Pump Speed 0.0 percent
# bacnet_point 0-10 Volt Input/Rate Cmd/SP Cmd 71.0 percent
#
# Cluster 139
# bacnet_point Operating Days 1536.0 days
# bacnet_point Operating Hours 3.0 hours
# bacnet_point Operating Days 922.0 days
# bacnet_point Operating Hours 21.0 hours
# bacnet_point Operating Days 2955.0 days
# bacnet_point Operating Hours 1.0 hours
# bacnet_point Operating Days 1871.0 days
# bacnet_point Operating Hours 16.0 hours
# bacnet_point RUN TIME 53636.0 hours
# bacnet_point Operating Days 1677.0 days
# bacnet_point Operating Hours 4.0 hours
# bacnet_point Operating Days 1485.0 days
# bacnet_point Operating Hours 2.0 hours
# bacnet_point Operating Days 3242.0 days
# bacnet_point Operating Hours 9.0 hours
# bacnet_point CompHours 1629.0 hours
# bacnet_point CondPumpOperHours 2693.0 hours
# bacnet_point EvapPumpOperHours 2793.0 hours
# bacnet_point CompHours 298.0 hours
# bacnet_point CondPumpOperHours 0.0 hours
# bacnet_point EvapPumpOperHours 0.0 hours
# bacnet_point Operating Days 73.0 days
# bacnet_point Operating Hours 0.0 hours
# bacnet_point Operating Days 1951.0 days
# bacnet_point Operating Hours 23.0 hours
# bacnet_point Operating Days 32.0 days
# bacnet_point Operating Hours 3.0 hours
# bacnet_point Operating Days 2709.0 days
# bacnet_point Operating Hours 17.0 hours
# bacnet_point RUN TIME 2406.0 hours
# bacnet_point RUN TIME 61591.0 hours
# bacnet_point RUN TIME 51.0 hours
# bacnet_point RUN TIME 56305.0 hours
# bacnet_point Operating Days 2636.0 days
# bacnet_point Operating Hours 23.0 hours
# bacnet_point Operating Days 2279.0 days
# bacnet_point Operating Hours 12.0 hours
# bacnet_point RUN TIME 63258.0 hours
# bacnet_point Operating Days 2667.0 days
# bacnet_point Operating Hours 19.0 hours
#
# Cluster 145
# bacnet_point Unit Temperature 0.0 degreesCelsius
# bacnet_point Unit Temperature 43.0 degreesCelsius
# bacnet_point Return Temperature 99.11709594726562 degreesFahrenheit
# bacnet_point Supply Temperature 94.06069946289062 degreesFahrenheit
# bacnet_point Temperature Units 257.0 noUnits
# bacnet_point Return Temperature 92.832275390625 degreesFahrenheit
# bacnet_point Supply Temperature 90.81661987304688 degreesFahrenheit
# bacnet_point Temperature Units 257.0 noUnits
# bacnet_point Return Temperature 45.789276123046875 degreesFahrenheit
# bacnet_point Supply Temperature 44.15704345703125 degreesFahrenheit
# bacnet_point Temperature Units 257.0 noUnits
# bacnet_point Unit Temperature 36.0 degreesCelsius
# bacnet_point Temperature 88.37067413330078 degreesFahrenheit
# bacnet_point Temperature Traverse 88.38188171386719 degreesFahrenheit
# bacnet_point Unit Temperature 24.0 degreesCelsius
# bacnet_point Unit Temperature 29.0 degreesCelsius
# bacnet_point Unit Temperature 27.0 degreesCelsius
# bacnet_point Unit Temperature 44.0 degreesCelsius
# bacnet_point GEO-FIELD-ENT-TEMP 86.5765609741211 degreesFahrenheit
# bacnet_point GEO-FIELD-ENT-TEMP 92.63749694824219 degreesFahrenheit
# bacnet_point GEO-FIELD-LVG-TEMP 85.71875 degreesFahrenheit
# bacnet_point GEO-FIELD-LVG-TEMP 87.2796859741211 degreesFahrenheit
# bacnet_point ChilledWaterDeltaT 1.08306884765625 degreesFahrenheit
# bacnet_point ChilledWaterDeltaT 1.58648681640625 degreesFahrenheit
# bacnet_point CondSatTemp 93.80000305175781 degreesFahrenheit
# bacnet_point DischargeTemp 102.9000015258789 degreesFahrenheit
# bacnet_point EntCondWaterTemp 90.5 degreesFahrenheit
# bacnet_point EntEvapWaterTemp 47.29999923706055 degreesFahrenheit
# bacnet_point EvapSatTemp 40.599998474121094 degreesFahrenheit
# bacnet_point HeatRecEntWaterTemp -327.6000061035156 degreesFahrenheit
# bacnet_point HeatRecLvgWaterTemp 0.0 degreesFahrenheit
# bacnet_point LiquidLineTemp 93.0 degreesFahrenheit
# bacnet_point LvgCondWaterTemp 92.5999984741211 degreesFahrenheit
# bacnet_point LvgEvapWaterTempComp 44.0 degreesFahrenheit
# bacnet_point LvgEvapWaterTempUnit 44.0 degreesFahrenheit
# bacnet_point OilFeedTemp 0.0 degreesFahrenheit
# bacnet_point OilSumpTemp 0.0 degreesFahrenheit
# bacnet_point OutdoorAirTemp 0.0 degreesFahrenheit
# bacnet_point AirOffEvapTemp 27.100000381469727 degreesCelsius
# bacnet_point AirOffEvapTemp_F 80.69999694824219 degreesFahrenheit
# bacnet_point OutsAirTemp 24.0 degreesCelsius
# bacnet_point OutsAirTemp_F 75.30000305175781 degreesFahrenheit
# bacnet_point PoolTemp1 28.100000381469727 degreesCelsius
# bacnet_point PoolTemp1_F 82.69999694824219 degreesFahrenheit
# bacnet_point PoolTemp2 28.100000381469727 degreesCelsius
# bacnet_point PoolTemp2_F 82.69999694824219 degreesFahrenheit
# bacnet_point RtnAirTemp 26.100000381469727 degreesCelsius
# bacnet_point RtnAirTemp_F 78.9000015258789 degreesFahrenheit
# bacnet_point SplyAirTemp_F 78.19999694824219 degreesFahrenheit
# bacnet_point SurfTemp 26.600000381469727 degreesCelsius
# bacnet_point SurfTemp_F 79.80000305175781 degreesFahrenheit
# bacnet_point CPU Board Temperature 42.418800354003906 degreesCelsius
# bacnet_point CPU Board Temperature 43.670326232910156 degreesCelsius
# bacnet_point Academic Corridor Average Zone Temp 71.49999237060547 degreesFahrenheit
# bacnet_point Academic Corridor Average Zone Temp 73.03333282470703 degreesFahrenheit
# bacnet_point Administration Wing Average Zone Temp 71.76666259765625 degreesFahrenheit
# bacnet_point Administration Wing Average Zone Temp 71.89999389648438 degreesFahrenheit
# bacnet_point Cafeteria and Kitchen Average Zone Temp 71.29999542236328 degreesFahrenheit
# bacnet_point Cafeteria and Kitchen Average Zone Temp 71.79999542236328 degreesFahrenheit
# bacnet_point Chilled Water Supply Temp 43.99531173706055 degreesFahrenheit
# bacnet_point Daycare Art Music Average Zone Temp 79.03333282470703 degreesFahrenheit
# bacnet_point DC_Weather_Temp 58.95000076293945 degreesFahrenheit
# bacnet_point DC_Weather_Temp 74.30000305175781 degreesFahrenheit
# bacnet_point First Floor WSHP Average Zone Temp 72.46666717529297 degreesFahrenheit
# bacnet_point First Floor WSHP Average Zone Temp 73.03333282470703 degreesFahrenheit
# bacnet_point Fourth Floor WSHP Average Zone Temp 72.83333587646484 degreesFahrenheit
# ...
# bacnet_point FCU12-1S-OCC-HEAT-SP 73.0 degreesFahrenheit
# bacnet_point FCU12-1S-SPACE-TEMP 75.4000015258789 degreesFahrenheit
# bacnet_point FCU12-1S-UNOCC-COOL-SP 85.0 degreesFahrenheit
# bacnet_point FCU12-1S-UNOCC-HEAT-SP 60.0 degreesFahrenheit
# bacnet_point FCU14-2N-COOL-LOOP-IN 73.0 degreesFahrenheit
# bacnet_point FCU14-2N-HEAT-LOOP-IN 71.0 degreesFahrenheit
# bacnet_point FCU14-2N-OCC-COOL-SP 73.0 degreesFahrenheit
# bacnet_point FCU14-2N-OCC-HEAT-SP 71.0 degreesFahrenheit
# bacnet_point FCU14-2N-UNOCC-COOL-SP 85.0 degreesFahrenheit
# bacnet_point FCU14-2N-UNOCC-HEAT-SP 60.0 degreesFahrenheit
# bacnet_point FCU15-2S-COOL-LOOP-IN 73.0 degreesFahrenheit
# bacnet_point FCU15-2S-HEAT-LOOP-IN 71.0 degreesFahrenheit
# bacnet_point FCU15-2S-OCC-COOL-SP 73.0 degreesFahrenheit
# bacnet_point FCU15-2S-OCC-HEAT-SP 71.0 degreesFahrenheit
# bacnet_point FCU15-2S-SPACE-TEMP 74.19999694824219 degreesFahrenheit
# bacnet_point FCU15-2S-UNOCC-COOL-SP 85.0 degreesFahrenheit
# bacnet_point FCU15-2S-UNOCC-HEAT-SP 60.0 degreesFahrenheit
# bacnet_point FCU-13-COOL-LOOP-IN 72.0 degreesFahrenheit
# bacnet_point FCU-13-OCC-COOL-SP 72.0 degreesFahrenheit
# bacnet_point FCU-13-SPACE-TEMP 72.80000305175781 degreesFahrenheit
# bacnet_point FCU-13-UNOCC-COOL-SP 85.0 degreesFahrenheit
#
# Cluster 89
# bacnet_point S_VcmxWshpTulsa[003].AlmGrp1 8.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].AlmGrp2 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].AlmGrp3 4.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].AlmSts 5.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].AppVer 100.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].ByPasDmp 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].CdFan1 100.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].CdFan2 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].ClSt 72.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].CO2Level 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].CoilTp 67.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].CtrlSts 2.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].CtrlTp 77.30000305175781 noUnits
# bacnet_point S_VcmxWshpTulsa[003].DptStM 55.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].DuctPr 1.809999942779541 noUnits
# bacnet_point S_VcmxWshpTulsa[003].EcoPos 50.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].EtCFM 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].ExRlys12 1.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].ExRlys34 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].HdPr1 417.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].HdPr2 194.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].HtSt 75.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].InRh 64.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].InRhStM 50.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].MdClPos 87.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].MdCmp2 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].MdHt2Pos 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].MdHtPos 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].OaCFM 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].OACfmStM 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].OaDwpt 69.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].OaRh 83.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].OaTp 74.30000305175781 noUnits
# bacnet_point S_VcmxWshpTulsa[003].OaWtbl 70.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].OnRlys 3.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].RaDmp 50.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].RaTp 74.5 noUnits
# bacnet_point S_VcmxWshpTulsa[003].RfPr 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].Rt2Pos 50.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].SaCFM 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].SaTp 72.80000305175781 noUnits
# bacnet_point S_VcmxWshpTulsa[003].SaTpStM 73.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].SpcTp 77.30000305175781 noUnits
# bacnet_point S_VcmxWshpTulsa[003].TpDmnd 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].UnitMode 6.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].VfdBwPos 100.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].VfdExPos 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].WaterTpA 102.30000305175781 noUnits
# bacnet_point S_VcmxWshpTulsa[003].WaterTpB 90.4000015258789 noUnits
# bacnet_point S_VcmxWshpTulsa[003].CO2St 500.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].CoilTpSt 45.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].DptSt 55.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].DuctPrSt 2.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].InRhSt 50.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].MinEcoSt 50.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].OACfmRs 0.10000000149011612 noUnits
# bacnet_point S_VcmxWshpTulsa[003].OACfmSt 0.10000000149011612 noUnits
# bacnet_point S_VcmxWshpTulsa[003].OaTpOst 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].OcpClSt 72.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].OcpHtSt 75.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].PreHtSp 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].RaTpOst 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].RfPrSt 0.05000000074505806 noUnits
# bacnet_point S_VcmxWshpTulsa[003].RmVFDPos -1.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].SaClSt 73.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].SaHtSt 67.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].SaTpOst 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].SchdFrc 1.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].SpcTpOst 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].UnClOst 8.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].UnHtOst 8.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].WmupSt 70.0 noUnits
# bacnet_point S_VcmxWshpTulsa[003].WtblSt 55.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].AlmGrp1 8.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].AlmGrp2 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].AlmGrp3 4.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].AlmGrp5 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].AlmSts 5.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].AppVer 100.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].ByPasDmp 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].CdFan1 25.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].CdFan2 25.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].CdFan21 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].CdFan22 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].ClSt 67.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].CO2Level 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].CoilTp 78.4000015258789 noUnits
# bacnet_point S_VcmxWshpTulsa[004].CtrlSts 2.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].CtrlTp 78.19999694824219 noUnits
# bacnet_point S_VcmxWshpTulsa[004].DptStM 55.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].DuctPr 1.7400000095367432 noUnits
# bacnet_point S_VcmxWshpTulsa[004].EcoPos 10.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].EtCFM 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].ExRlys12 1.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].ExRlys34 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].HdPr1 236.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].HdPr2 245.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].HdPr21 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].HdPr22 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].HtSt 64.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].InRh 47.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].InRhStM 60.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].MdClPos 100.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].MdCmp2 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].MdHt2Pos 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].MdHtPos 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].OaCFM 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].OACfmStM 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].OaDwpt 68.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].OaRh 80.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].OaTp 75.5 noUnits
# bacnet_point S_VcmxWshpTulsa[004].OaWtbl 71.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].OnRlys 15.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].RaDmp 90.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].RaTp 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].RfPr -0.009999999776482582 noUnits
# bacnet_point S_VcmxWshpTulsa[004].Rt2Pos 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].SaCFM 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].SaTp 81.69999694824219 noUnits
# bacnet_point S_VcmxWshpTulsa[004].SaTpStM 50.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].SpcTp 78.19999694824219 noUnits
# bacnet_point S_VcmxWshpTulsa[004].T24EcFb 5.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].TpDmnd 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].UnitMode 6.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].VfdBwPos 100.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].VfdExPos 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].WaterTpA 89.9000015258789 noUnits
# bacnet_point S_VcmxWshpTulsa[004].WaterTpB 90.30000305175781 noUnits
# bacnet_point S_VcmxWshpTulsa[004].ClHiRt 55.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].ClLoRt 55.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].CO2St 900.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].CoilTpSt 45.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].DptSt 55.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].DuctPrSt 2.559999942779541 noUnits
# bacnet_point S_VcmxWshpTulsa[004].HtHiRt 55.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].HtLoRt 55.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].InRhSt 60.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].MinEcoSt 10.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].OACfmRs 0.10000000149011612 noUnits
# bacnet_point S_VcmxWshpTulsa[004].OACfmSt 0.10000000149011612 noUnits
# bacnet_point S_VcmxWshpTulsa[004].OaTpOst 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].OcpClSt 67.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].OcpHtSt 64.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].PreHtSp 32.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].RaTpOst 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].RfPrSt 0.05000000074505806 noUnits
# bacnet_point S_VcmxWshpTulsa[004].RmVFDPos -1.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].SaClRt 55.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].SaClSt 50.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].SaHtRt 65.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].SaHtSt 70.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].SaTpOst 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].SchdFrc 1.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].SpcTpOst 0.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].UnClOst 10.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].UnHtOst 10.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].WmupSt 70.0 noUnits
# bacnet_point S_VcmxWshpTulsa[004].WtblSt 55.0 noUnits
#
# Cluster 6
# bacnet_point S_VcmxWshpTulsa[003].A1LktAlm active
# bacnet_point S_VcmxWshpTulsa[003].A1LSPAlm inactive
# bacnet_point S_VcmxWshpTulsa[003].A2LktAlm inactive
# bacnet_point S_VcmxWshpTulsa[003].A2LSPAlm inactive
# bacnet_point S_VcmxWshpTulsa[003].B1LktAlm inactive
# bacnet_point S_VcmxWshpTulsa[003].B1LSPAlm inactive
# bacnet_point S_VcmxWshpTulsa[003].B2LktAlm inactive
# bacnet_point S_VcmxWshpTulsa[003].B2LSPAlm inactive
# bacnet_point S_VcmxWshpTulsa[003].ClEnbl active
# bacnet_point S_VcmxWshpTulsa[003].CO2Cfg active
# bacnet_point S_VcmxWshpTulsa[003].ComMAlm inactive
# bacnet_point S_VcmxWshpTulsa[003].CtrlTpCF active
# bacnet_point S_VcmxWshpTulsa[003].CtrlTpHF inactive
# bacnet_point S_VcmxWshpTulsa[003].DrtFlAlm inactive
# bacnet_point S_VcmxWshpTulsa[003].EcoEnbl inactive
# bacnet_point S_VcmxWshpTulsa[003].ExRly1 active
# bacnet_point S_VcmxWshpTulsa[003].ExRly10 inactive
# bacnet_point S_VcmxWshpTulsa[003].ExRly11 inactive
# bacnet_point S_VcmxWshpTulsa[003].ExRly12 inactive
# bacnet_point S_VcmxWshpTulsa[003].ExRly13 inactive
# bacnet_point S_VcmxWshpTulsa[003].ExRly14 inactive
# bacnet_point S_VcmxWshpTulsa[003].ExRly15 inactive
# bacnet_point S_VcmxWshpTulsa[003].ExRly16 inactive
# bacnet_point S_VcmxWshpTulsa[003].ExRly2 inactive
# bacnet_point S_VcmxWshpTulsa[003].ExRly3 inactive
# bacnet_point S_VcmxWshpTulsa[003].ExRly4 inactive
# bacnet_point S_VcmxWshpTulsa[003].ExRly5 inactive
# bacnet_point S_VcmxWshpTulsa[003].ExRly6 inactive
# bacnet_point S_VcmxWshpTulsa[003].ExRly7 inactive
# bacnet_point S_VcmxWshpTulsa[003].ExRly8 inactive
# bacnet_point S_VcmxWshpTulsa[003].ExRly9 inactive
# bacnet_point S_VcmxWshpTulsa[003].FanDly inactive
# bacnet_point S_VcmxWshpTulsa[003].HiSaAlm inactive
# bacnet_point S_VcmxWshpTulsa[003].HtEnbl inactive
# bacnet_point S_VcmxWshpTulsa[003].LoSaAlm inactive
# bacnet_point S_VcmxWshpTulsa[003].LWT1Alm inactive
# bacnet_point S_VcmxWshpTulsa[003].LWT2Alm inactive
# bacnet_point S_VcmxWshpTulsa[003].MchClAlm inactive
# bacnet_point S_VcmxWshpTulsa[003].MchHtAlm inactive
# bacnet_point S_VcmxWshpTulsa[003].MdHt2Ins inactive
# bacnet_point S_VcmxWshpTulsa[003].OaTpAlm inactive
# bacnet_point S_VcmxWshpTulsa[003].OnRly1 active
# bacnet_point S_VcmxWshpTulsa[003].OnRly2 active
# bacnet_point S_VcmxWshpTulsa[003].OnRly3 inactive
# bacnet_point S_VcmxWshpTulsa[003].OnRly4 inactive
# bacnet_point S_VcmxWshpTulsa[003].OnRly5 inactive
# bacnet_point S_VcmxWshpTulsa[003].PofAlm inactive
# bacnet_point S_VcmxWshpTulsa[003].PofCfg active
# bacnet_point S_VcmxWshpTulsa[003].POWF1Alm inactive
# bacnet_point S_VcmxWshpTulsa[003].POWF2Alm inactive
# bacnet_point S_VcmxWshpTulsa[003].Rt2Ins active
# bacnet_point S_VcmxWshpTulsa[003].SaTpAlm inactive
# bacnet_point S_VcmxWshpTulsa[003].SmokeAlm inactive
# bacnet_point S_VcmxWshpTulsa[003].SpcTpAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].A1LktAlm active
# bacnet_point S_VcmxWshpTulsa[004].A1LSPAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].A2LktAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].A2LSPAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].B1LktAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].B1LSPAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].B2LktAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].B2LSPAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].ClEnbl active
# bacnet_point S_VcmxWshpTulsa[004].CO2Cfg active
# bacnet_point S_VcmxWshpTulsa[004].ComMAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].CtrlTpCF active
# bacnet_point S_VcmxWshpTulsa[004].CtrlTpHF inactive
# bacnet_point S_VcmxWshpTulsa[004].DrtFlAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].EcoEnbl inactive
# bacnet_point S_VcmxWshpTulsa[004].ExRly1 active
# bacnet_point S_VcmxWshpTulsa[004].ExRly10 inactive
# bacnet_point S_VcmxWshpTulsa[004].ExRly11 inactive
# bacnet_point S_VcmxWshpTulsa[004].ExRly12 inactive
# bacnet_point S_VcmxWshpTulsa[004].ExRly13 inactive
# bacnet_point S_VcmxWshpTulsa[004].ExRly14 inactive
# bacnet_point S_VcmxWshpTulsa[004].ExRly15 inactive
# bacnet_point S_VcmxWshpTulsa[004].ExRly16 inactive
# bacnet_point S_VcmxWshpTulsa[004].ExRly2 inactive
# bacnet_point S_VcmxWshpTulsa[004].ExRly3 inactive
# bacnet_point S_VcmxWshpTulsa[004].ExRly4 inactive
# bacnet_point S_VcmxWshpTulsa[004].ExRly5 inactive
# bacnet_point S_VcmxWshpTulsa[004].ExRly6 inactive
# bacnet_point S_VcmxWshpTulsa[004].ExRly7 inactive
# bacnet_point S_VcmxWshpTulsa[004].ExRly8 inactive
# bacnet_point S_VcmxWshpTulsa[004].ExRly9 inactive
# bacnet_point S_VcmxWshpTulsa[004].FanDly inactive
# bacnet_point S_VcmxWshpTulsa[004].HiSaAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].HtEnbl inactive
# bacnet_point S_VcmxWshpTulsa[004].LoSaAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].LWT1Alm inactive
# bacnet_point S_VcmxWshpTulsa[004].LWT2Alm inactive
# bacnet_point S_VcmxWshpTulsa[004].MchClAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].MchHtAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].MdHt2Ins inactive
# bacnet_point S_VcmxWshpTulsa[004].OaTpAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].OnRly1 active
# bacnet_point S_VcmxWshpTulsa[004].OnRly2 active
# bacnet_point S_VcmxWshpTulsa[004].OnRly3 active
# bacnet_point S_VcmxWshpTulsa[004].OnRly4 active
# bacnet_point S_VcmxWshpTulsa[004].OnRly5 inactive
# bacnet_point S_VcmxWshpTulsa[004].PofAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].PofCfg active
# bacnet_point S_VcmxWshpTulsa[004].POWF1Alm inactive
# bacnet_point S_VcmxWshpTulsa[004].POWF2Alm inactive
# bacnet_point S_VcmxWshpTulsa[004].RaTpAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].Rt2Ins active
# bacnet_point S_VcmxWshpTulsa[004].SaTpAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].SmokeAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].SpcTpAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].T24DpAlm inactive
# bacnet_point S_VcmxWshpTulsa[004].T24EWISN inactive
# bacnet_point S_VcmxWshpTulsa[004].T24ExsOA inactive
# bacnet_point S_VcmxWshpTulsa[004].T24NEWS inactive
# bacnet_point S_VcmxWshpTulsa[004].T24TpAlm inactive

# %%
from openai import OpenAI
client = OpenAI()

# %%
device_names = []
for document in cluster_dict[0]:
    device_names.append(document.page_content)

names = "\n".join(device_names)
names
# Out:
# 'Engineering\nEngineering\nEngineering\nBTU METER 1020\nBTU METER 1021\nBTU METER 1022\nAHU-3 AFMS\nATV212\nCHILLED/COND WATER\nMTIIChillerUC100001\npCOWeb88004\nenteliBUS Manager 4104766\nMTIIChillerUC200002\nVolttron BACnet driver\nHOT WATER PLANT\n\nA-WING FLRS 3&4 DOAS2\nDevice_0030de05fef2\nB-WING VAVS\nAHU1\nAHU2\nAHU3\nAHU5\nAHU6\nAHU7\nC-WING RTU DOAS1&6\nA-WING FLOORS 1&2\nAHU-1 AFMS\nBTU METER 2020\nATV212\nEF-18\nFCU-11&12 1ST FLR\nFCU-14&15 2ND FLR\nGARAGE EXHAUST\nAHU-7 AFMS\nATV212\nATV212_005\nEF-17\nEF-23\nFCU-13\npCOnet77001\nATV212\nAHU-5 AFMS\nAHU-2 AFMS\nATV212\nAHU-6 AFMS\nAHU-4 AFMS\nWATT_BACnet\nWATT_BACnet_66005\npCOnet77006\nDHW\nEF-5&9\nDev_MSTP'
